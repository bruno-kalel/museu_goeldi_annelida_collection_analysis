# %%
import pandas as pd
import numpy as np
from geopy.geocoders import GoogleV3
import re

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# **Visualizar o dataframe, checar quantidade de colunas com valores fixos(mesmo valor da coluna para todos os registros) e checar para valores nan presentes. Atencao que valores nan unicos para uma mesma coluna nos diversos registros vao ser, primeiro, descobertos no processo de checagem de valores fixos**

# %%
dados = pd.read_csv('/content/occurrence.txt', engine= 'python', sep='        ') #separador utilizado na formatação do arquivo txt

# %%
dados.head()
# Out:
#        gbifID                                       accessRights  \
# 0  2365686427  Creative Commons Attribution Non Commercial (C...
# 1  2365686418  Creative Commons Attribution Non Commercial (C...
# 2  2365686416  Creative Commons Attribution Non Commercial (C...
# 3  2365686414  Creative Commons Attribution Non Commercial (C...
# 4  2365686412  Creative Commons Attribution Non Commercial (C...
#
#    bibliographicCitation  language       license  modified  publisher  \
# 0                    NaN       NaN  CC_BY_NC_4_0       NaN        NaN
# 1                    NaN       NaN  CC_BY_NC_4_0       NaN        NaN
# 2                    NaN       NaN  CC_BY_NC_4_0       NaN        NaN
# 3                    NaN       NaN  CC_BY_NC_4_0       NaN        NaN
# 4                    NaN       NaN  CC_BY_NC_4_0       NaN        NaN
#
#    references                         rightsHolder  type  institutionID  \
# 0         NaN  Museu Paraense Emílio Goeldi (MPEG)   NaN            NaN
# 1         NaN  Museu Paraense Emílio Goeldi (MPEG)   NaN            NaN
# 2         NaN  Museu Paraense Emílio Goeldi (MPEG)   NaN            NaN
# 3         NaN  Museu Paraense Emílio Goeldi (MPEG)   NaN            NaN
# 4         NaN  Museu Paraense Emílio Goeldi (MPEG)   NaN            NaN
#
#    collectionID  datasetID institutionCode collectionCode  datasetName  \
# 0           NaN        NaN            MPEG            ANL          NaN
# 1           NaN        NaN            MPEG            ANL          NaN
# 2           NaN        NaN            MPEG            ANL          NaN
# 3           NaN        NaN            MPEG            ANL          NaN
# 4           NaN        NaN            MPEG            ANL          NaN
#
#    ownerInstitutionCode       basisOfRecord  informationWithheld  \
# 0                   NaN  PRESERVED_SPECIMEN                  NaN
# 1                   NaN  PRESERVED_SPECIMEN                  NaN
# 2                   NaN  PRESERVED_SPECIMEN                  NaN
# 3                   NaN  PRESERVED_SPECIMEN                  NaN
# 4                   NaN  PRESERVED_SPECIMEN                  NaN
#
#    dataGeneralizations  dynamicProperties     occurrenceID    catalogNumber  \
# 0                  NaN                NaN  MPEG.ANL 001101  MPEG.ANL 001101
# 1                  NaN                NaN  MPEG.ANL 001596  MPEG.ANL 001596
# 2                  NaN                NaN  MPEG.ANL 001635  MPEG.ANL 001635
# 3                  NaN                NaN  MPEG.ANL 001031  MPEG.ANL 001031
# 4                  NaN                NaN  MPEG.ANL 001036  MPEG.ANL 001036
#
#    recordNumber                                         recordedBy  \
# 0           NaN          Beckman, Ruana; Pena, José; Souza, Raíssa
# 1           NaN  Sousa, Sandriel; Hernández, Luis; Rousseau, Gu...
# 2           NaN      Sousa, Anny; Sousa, Sandriel; Hernández, Luis
# 3           NaN          Beckman, Ruana; Pena, José; Souza, Raíssa
# 4           NaN          Beckman, Ruana; Pena, José; Souza, Raíssa
#
#    recordedByID  individualCount  organismQuantity  organismQuantityType  sex  \
# 0           NaN              NaN               NaN                   NaN  NaN
# 1           NaN              NaN               NaN                   NaN  NaN
# 2           NaN              NaN               NaN                   NaN  NaN
# 3           NaN              NaN               NaN                   NaN  NaN
# 4           NaN              NaN               NaN                   NaN  NaN
#
#    lifeStage  reproductiveCondition  behavior  establishmentMeans  \
# 0        NaN                    NaN       NaN                 NaN
# 1        NaN                    NaN       NaN                 NaN
# 2        NaN                    NaN       NaN                 NaN
# 3        NaN                    NaN       NaN                 NaN
# 4        NaN                    NaN       NaN                 NaN
#
#    degreeOfEstablishment  pathway  georeferenceVerificationStatus  \
# 0                    NaN      NaN                             NaN
# 1                    NaN      NaN                             NaN
# 2                    NaN      NaN                             NaN
# 3                    NaN      NaN                             NaN
# 4                    NaN      NaN                             NaN
#
#   occurrenceStatus preparations  disposition  associatedOccurrences  \
# 0          PRESENT   Etanol - 3          NaN                    NaN
# 1          PRESENT   Etanol - 1          NaN                    NaN
# 2          PRESENT   Etanol - 1          NaN                    NaN
# 3          PRESENT   Etanol - 1          NaN                    NaN
# 4          PRESENT  Etanol - 17          NaN                    NaN
#
#    associatedReferences  associatedSequences  associatedTaxa  \
# 0                   NaN                  NaN             NaN
# 1                   NaN                  NaN             NaN
# 2                   NaN                  NaN             NaN
# 3                   NaN                  NaN             NaN
# 4                   NaN                  NaN             NaN
#
#    otherCatalogNumbers  occurrenceRemarks  organismID  organismName  \
# 0                  NaN                NaN         NaN           NaN
# 1                  NaN                NaN         NaN           NaN
# 2                  NaN                NaN         NaN           NaN
# 3                  NaN                NaN         NaN           NaN
# 4                  NaN                NaN         NaN           NaN
#
#    organismScope  associatedOrganisms  previousIdentifications  \
# 0            NaN                  NaN                      NaN
# 1            NaN                  NaN                      NaN
# 2            NaN                  NaN                      NaN
# 3            NaN                  NaN                      NaN
# 4            NaN                  NaN                      NaN
#
#    organismRemarks  materialSampleID  eventID  parentEventID  fieldNumber  \
# 0              NaN               NaN      NaN            NaN          NaN
# 1              NaN               NaN      NaN            NaN          NaN
# 2              NaN               NaN      NaN            NaN          NaN
# 3              NaN               NaN      NaN            NaN          NaN
# 4              NaN               NaN      NaN            NaN          NaN
#
#              eventDate  eventTime  startDayOfYear  endDayOfYear    year  \
# 0  2017-08-30T00:00:00        NaN             NaN           NaN  2017.0
# 1  2018-08-15T00:00:00        NaN             NaN           NaN  2018.0
# 2  2019-02-12T00:00:00        NaN             NaN           NaN  2019.0
# 3  2017-08-30T00:00:00        NaN             NaN           NaN  2017.0
# 4  2017-08-30T00:00:00        NaN             NaN           NaN  2017.0
#
#    month   day  verbatimEventDate  habitat  samplingProtocol  sampleSizeValue  \
# 0    8.0  30.0                NaN      NaN               NaN              NaN
# 1    8.0  15.0                NaN      NaN               NaN              NaN
# 2    2.0  12.0                NaN      NaN               NaN              NaN
# 3    8.0  30.0                NaN      NaN               NaN              NaN
# 4    8.0  30.0                NaN      NaN               NaN              NaN
#
#    sampleSizeUnit  samplingEffort  fieldNotes eventRemarks  locationID  \
# 0             NaN             NaN         NaN          NaN         NaN
# 1             NaN             NaN         NaN          NaN         NaN
# 2             NaN             NaN         NaN          NaN         NaN
# 3             NaN             NaN         NaN          NaN         NaN
# 4             NaN             NaN         NaN          NaN         NaN
#
#    higherGeographyID     higherGeography      continent  waterBody  \
# 0                NaN         Pará, Belém            NaN        NaN
# 1                NaN  Maranhão, São Luís  SOUTH_AMERICA        NaN
# 2                NaN    Maranhão, Caxias  SOUTH_AMERICA        NaN
# 3                NaN         Pará, Belém            NaN        NaN
# 4                NaN         Pará, Belém            NaN        NaN
#
#    islandGroup  island countryCode stateProvince    county  municipality  \
# 0          NaN     NaN          BR          Pará     Belém           NaN
# 1          NaN     NaN          BR      Maranhão  São Luís           NaN
# 2          NaN     NaN          BR      Maranhão    Caxias           NaN
# 3          NaN     NaN          BR          Pará     Belém           NaN
# 4          NaN     NaN          BR          Pará     Belém           NaN
#
#                locality  verbatimLocality  verbatimElevation  verticalDatum  \
# 0               Mocambo               NaN                NaN            NaN
# 1        Fazenda Escola               NaN                NaN            NaN
# 2  Santa Tereza Village               NaN                NaN            NaN
# 3               Mocambo               NaN                NaN            NaN
# 4               Mocambo               NaN                NaN            NaN
#
#    verbatimDepth  minimumDistanceAboveSurfaceInMeters  \
# 0            NaN                                  NaN
# 1            NaN                                  NaN
# 2            NaN                                  NaN
# 3            NaN                                  NaN
# 4            NaN                                  NaN
#
#    maximumDistanceAboveSurfaceInMeters  locationAccordingTo  locationRemarks  \
# 0                                  NaN                  NaN              NaN
# 1                                  NaN                  NaN              NaN
# 2                                  NaN                  NaN              NaN
# 3                                  NaN                  NaN              NaN
# 4                                  NaN                  NaN              NaN
#
#    decimalLatitude  decimalLongitude  coordinateUncertaintyInMeters  \
# 0         1.440694        -48.411250                            NaN
# 1        -4.587222        -44.208611                            NaN
# 2        -4.899722        -43.470833                            NaN
# 3         1.440694        -48.411250                            NaN
# 4         1.440694        -48.411250                            NaN
#
#    coordinatePrecision  pointRadiusSpatialFit  verbatimCoordinateSystem  \
# 0                  NaN                    NaN                       NaN
# 1                  NaN                    NaN                       NaN
# 2                  NaN                    NaN                       NaN
# 3                  NaN                    NaN                       NaN
# 4                  NaN                    NaN                       NaN
#
#    verbatimSRS  footprintWKT  footprintSRS  footprintSpatialFit  \
# 0          NaN           NaN           NaN                  NaN
# 1          NaN           NaN           NaN                  NaN
# 2          NaN           NaN           NaN                  NaN
# 3          NaN           NaN           NaN                  NaN
# 4          NaN           NaN           NaN                  NaN
#
#    georeferencedBy  georeferencedDate  georeferenceProtocol  \
# 0              NaN                NaN                   NaN
# 1              NaN                NaN                   NaN
# 2              NaN                NaN                   NaN
# 3              NaN                NaN                   NaN
# 4              NaN                NaN                   NaN
#
#    georeferenceSources  georeferenceRemarks  geologicalContextID  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#    earliestEonOrLowestEonothem  latestEonOrHighestEonothem  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#    earliestEraOrLowestErathem  latestEraOrHighestErathem  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    earliestPeriodOrLowestSystem  latestPeriodOrHighestSystem  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#    earliestEpochOrLowestSeries  latestEpochOrHighestSeries  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#    earliestAgeOrLowestStage  latestAgeOrHighestStage  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
#    lowestBiostratigraphicZone  highestBiostratigraphicZone  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    lithostratigraphicTerms  group  formation  member  bed  identificationID  \
# 0                      NaN    NaN        NaN     NaN  NaN               NaN
# 1                      NaN    NaN        NaN     NaN  NaN               NaN
# 2                      NaN    NaN        NaN     NaN  NaN               NaN
# 3                      NaN    NaN        NaN     NaN  NaN               NaN
# 4                      NaN    NaN        NaN     NaN  NaN               NaN
#
#    verbatimIdentification  identificationQualifier typeStatus  identifiedBy  \
# 0                     NaN                      NaN        NaN           NaN
# 1                     NaN                      NaN        NaN           NaN
# 2                     NaN                      NaN        NaN           NaN
# 3                     NaN                      NaN        NaN           NaN
# 4                     NaN                      NaN        NaN           NaN
#
#    identifiedByID  dateIdentified  identificationReferences  \
# 0             NaN             NaN                       NaN
# 1             NaN             NaN                       NaN
# 2             NaN             NaN                       NaN
# 3             NaN             NaN                       NaN
# 4             NaN             NaN                       NaN
#
#    identificationVerificationStatus  identificationRemarks  taxonID  \
# 0                               NaN                    NaN      NaN
# 1                               NaN                    NaN      NaN
# 2                               NaN                    NaN      NaN
# 3                               NaN                    NaN      NaN
# 4                               NaN                    NaN      NaN
#
#    scientificNameID  acceptedNameUsageID  parentNameUsageID  \
# 0               NaN                  NaN                NaN
# 1               NaN                  NaN                NaN
# 2               NaN                  NaN                NaN
# 3               NaN                  NaN                NaN
# 4               NaN                  NaN                NaN
#
#    originalNameUsageID  nameAccordingToID  namePublishedInID  taxonConceptID  \
# 0                  NaN                NaN                NaN             NaN
# 1                  NaN                NaN                NaN             NaN
# 2                  NaN                NaN                NaN             NaN
# 3                  NaN                NaN                NaN             NaN
# 4                  NaN                NaN                NaN             NaN
#
#                   scientificName  acceptedNameUsage  parentNameUsage  \
# 0                    Pontoscolex                NaN              NaN
# 1  Liodrilus mendesi Righi, 1994                NaN              NaN
# 2  Liodrilus mendesi Righi, 1994                NaN              NaN
# 3                    Pontoscolex                NaN              NaN
# 4                    Pontoscolex                NaN              NaN
#
#    originalNameUsage  nameAccordingTo  namePublishedIn  namePublishedInYear  \
# 0                NaN              NaN              NaN                  NaN
# 1                NaN              NaN              NaN                  NaN
# 2                NaN              NaN              NaN                  NaN
# 3                NaN              NaN              NaN                  NaN
# 4                NaN              NaN              NaN                  NaN
#
#    higherClassification   kingdom    phylum       class        order  \
# 0                   NaN  Animalia  Annelida  Clitellata  Haplotaxida
# 1                   NaN  Animalia  Annelida  Clitellata          NaN
# 2                   NaN  Animalia  Annelida  Clitellata          NaN
# 3                   NaN  Animalia  Annelida  Clitellata  Haplotaxida
# 4                   NaN  Animalia  Annelida  Clitellata  Haplotaxida
#
#              family  subfamily        genus  genericName  subgenus  \
# 0  Glossoscolecidae        NaN  Pontoscolex  Pontoscolex       NaN
# 1               NaN        NaN    Liodrilus    Liodrilus       NaN
# 2               NaN        NaN    Liodrilus    Liodrilus       NaN
# 3  Glossoscolecidae        NaN  Pontoscolex  Pontoscolex       NaN
# 4  Glossoscolecidae        NaN  Pontoscolex  Pontoscolex       NaN
#
#    infragenericEpithet specificEpithet infraspecificEpithet  cultivarEpithet  \
# 0                  NaN             NaN                  NaN              NaN
# 1                  NaN         mendesi                  NaN              NaN
# 2                  NaN         mendesi                  NaN              NaN
# 3                  NaN             NaN                  NaN              NaN
# 4                  NaN             NaN                  NaN              NaN
#
#   taxonRank  verbatimTaxonRank  vernacularName  nomenclaturalCode  \
# 0     GENUS                NaN             NaN                NaN
# 1   SPECIES                NaN             NaN                NaN
# 2   SPECIES                NaN             NaN                NaN
# 3     GENUS                NaN             NaN                NaN
# 4     GENUS                NaN             NaN                NaN
#
#   taxonomicStatus  nomenclaturalStatus  taxonRemarks  \
# 0        DOUBTFUL                  NaN           NaN
# 1        ACCEPTED                  NaN           NaN
# 2        ACCEPTED                  NaN           NaN
# 3        DOUBTFUL                  NaN           NaN
# 4        DOUBTFUL                  NaN           NaN
#
#                              datasetKey publishingCountry  \
# 0  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 1  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 2  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 3  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 4  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
#
#             lastInterpreted  elevation  elevationAccuracy  depth  \
# 0  2023-09-07T09:19:05.952Z        NaN                NaN    NaN
# 1  2023-09-07T09:19:05.949Z        NaN                NaN    NaN
# 2  2023-09-07T09:19:05.937Z        NaN                NaN    NaN
# 3  2023-09-07T09:19:05.946Z        NaN                NaN    NaN
# 4  2023-09-07T09:19:05.946Z        NaN                NaN    NaN
#
#    depthAccuracy  distanceFromCentroidInMeters  \
# 0            NaN                           NaN
# 1            NaN                           NaN
# 2            NaN                           NaN
# 3            NaN                           NaN
# 4            NaN                           NaN
#
#                                                issue  mediaType  \
# 0  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...        NaN
# 1  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...        NaN
# 2  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...        NaN
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...        NaN
# 4  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...        NaN
#
#    hasCoordinate  hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  \
# 0           True                 True   2308740         2308740.0           1
# 1           True                False   9512479         9512479.0           1
# 2           True                False   9512479         9512479.0           1
# 3           True                 True   2308740         2308740.0           1
# 4           True                 True   2308740         2308740.0           1
#
#    phylumKey  classKey  orderKey  familyKey   genusKey  subgenusKey  \
# 0       42.0     255.0     472.0     3567.0  2308740.0          NaN
# 1       42.0     255.0       NaN        NaN  4813824.0          NaN
# 2       42.0     255.0       NaN        NaN  4813824.0          NaN
# 3       42.0     255.0     472.0     3567.0  2308740.0          NaN
# 4       42.0     255.0     472.0     3567.0  2308740.0          NaN
#
#    speciesKey            species         acceptedScientificName  \
# 0         NaN                NaN                    Pontoscolex
# 1   9512479.0  Liodrilus mendesi  Liodrilus mendesi Righi, 1994
# 2   9512479.0  Liodrilus mendesi  Liodrilus mendesi Righi, 1994
# 3         NaN                NaN                    Pontoscolex
# 4         NaN                NaN                    Pontoscolex
#
#     verbatimScientificName  typifiedName protocol                lastParsed  \
# 0  Pontoscolex Corethrurus           NaN      EML  2023-09-07T09:19:05.952Z
# 1        Liodrilus mendesi           NaN      EML  2023-09-07T09:19:05.949Z
# 2        Liodrilus mendesi           NaN      EML  2023-09-07T09:19:05.937Z
# 3  Pontoscolex Corethrurus           NaN      EML  2023-09-07T09:19:05.946Z
# 4  Pontoscolex Corethrurus           NaN      EML  2023-09-07T09:19:05.946Z
#
#                 lastCrawled repatriated  relativeOrganismQuantity  projectId  \
# 0  2023-01-07T11:25:05.817Z       false                       NaN        NaN
# 1  2023-01-07T11:25:05.817Z       false                       NaN        NaN
# 2  2023-01-07T11:25:05.817Z       false                       NaN        NaN
# 3  2023-01-07T11:25:05.817Z       false                       NaN        NaN
# 4  2023-01-07T11:25:05.817Z       false                       NaN        NaN
#
#   level0Gid level0Name level1Gid level1Name    level2Gid level2Name  \
# 0      None       None      None       None         None       None
# 1       BRA     Brazil  BRA.10_1   Maranhão  BRA.10.59_2       Codó
# 2       BRA     Brazil  BRA.10_1   Maranhão  BRA.10.52_2     Caxias
# 3      None       None      None       None         None       None
# 4      None       None      None       None         None       None
#
#    level3Gid  level3Name iucnRedListCategory  eventType
# 0        NaN         NaN                None        NaN
# 1        NaN         NaN                  NE        NaN
# 2        NaN         NaN                  NE        NaN
# 3        NaN         NaN                None        NaN
# 4        NaN         NaN                None        NaN

# %% [markdown]
# Presença de vários valores NAN

# %%
dados.shape
# Out:
# (892, 212)

# %% [markdown]
# 892 registros, cada um com 212 colunas

# %%
dados.isna().sum()
# Out:
# gbifID                     0
# accessRights               0
# bibliographicCitation    892
# language                 892
# license                    0
#                         ...
# level2Name               288
# level3Gid                892
# level3Name               892
# iucnRedListCategory      529
# eventType                892
# Length: 212, dtype: int64

# %%
(dados.isna().sum() == 0).sum()
# Out:
# 24

# %% [markdown]
# Apenas 24 colunas estao completas. Ainda tenho que checar se os tipos presentes correspondem a descrição da coluna. Fazer após lidar com os valores nans

# %% [markdown]
# Pegar todas as colunas que possuem apenas valores nan, guardar seu nome numa lista e remover do dataframe original. Guardar na lista para poder lidar com esse labels no banco, formatacao exige a presenca delas, mesmo sem dados

# %%
lista_label_colunas_totalmente_nan = []

# %%
quantidade_colunas_totalmente_nan = 0

for column in dados.columns:

  print(column)

  if dados[column].isna().sum() == dados.shape[0]:

    quantidade_colunas_totalmente_nan += 1

    lista_label_colunas_totalmente_nan.append(column)

print(f'quantidade_colunas_totalmente_nan: {quantidade_colunas_totalmente_nan}')
# Out:
# gbifID
# accessRights
# bibliographicCitation
# language
# license
# modified
# publisher
# references
# rightsHolder
# type
# institutionID
# collectionID
# datasetID
# institutionCode
# collectionCode
# datasetName
# ownerInstitutionCode
# basisOfRecord
# informationWithheld
# dataGeneralizations
# dynamicProperties
# occurrenceID
# catalogNumber
# recordNumber
# recordedBy
# recordedByID
# individualCount
# organismQuantity
# organismQuantityType
# sex
# lifeStage
# reproductiveCondition
# behavior
# establishmentMeans
# degreeOfEstablishment
# pathway
# georeferenceVerificationStatus
# occurrenceStatus
# preparations
# disposition
# associatedOccurrences
# associatedReferences
# associatedSequences
# associatedTaxa
# otherCatalogNumbers
# occurrenceRemarks
# organismID
# organismName
# organismScope
# associatedOrganisms
# previousIdentifications
# organismRemarks
# materialSampleID
# eventID
# parentEventID
# fieldNumber
# eventDate
# eventTime
# startDayOfYear
# endDayOfYear
# year
# month
# day
# verbatimEventDate
# habitat
# samplingProtocol
# sampleSizeValue
# sampleSizeUnit
# samplingEffort
# fieldNotes
# eventRemarks
# locationID
# higherGeographyID
# higherGeography
# continent
# waterBody
# islandGroup
# island
# countryCode
# stateProvince
# county
# municipality
# locality
# verbatimLocality
# verbatimElevation
# verticalDatum
# verbatimDepth
# minimumDistanceAboveSurfaceInMeters
# maximumDistanceAboveSurfaceInMeters
# locationAccordingTo
# locationRemarks
# decimalLatitude
# decimalLongitude
# coordinateUncertaintyInMeters
# coordinatePrecision
# pointRadiusSpatialFit
# verbatimCoordinateSystem
# verbatimSRS
# footprintWKT
# footprintSRS
# footprintSpatialFit
# georeferencedBy
# georeferencedDate
# georeferenceProtocol
# georeferenceSources
# georeferenceRemarks
# geologicalContextID
# earliestEonOrLowestEonothem
# latestEonOrHighestEonothem
# earliestEraOrLowestErathem
# latestEraOrHighestErathem
# earliestPeriodOrLowestSystem
# latestPeriodOrHighestSystem
# earliestEpochOrLowestSeries
# latestEpochOrHighestSeries
# earliestAgeOrLowestStage
# latestAgeOrHighestStage
# lowestBiostratigraphicZone
# highestBiostratigraphicZone
# lithostratigraphicTerms
# group
# formation
# member
# bed
# identificationID
# verbatimIdentification
# identificationQualifier
# typeStatus
# identifiedBy
# identifiedByID
# dateIdentified
# identificationReferences
# identificationVerificationStatus
# identificationRemarks
# taxonID
# scientificNameID
# acceptedNameUsageID
# parentNameUsageID
# originalNameUsageID
# nameAccordingToID
# namePublishedInID
# taxonConceptID
# scientificName
# acceptedNameUsage
# parentNameUsage
# originalNameUsage
# nameAccordingTo
# namePublishedIn
# namePublishedInYear
# higherClassification
# kingdom
# phylum
# class
# order
# family
# subfamily
# genus
# genericName
# subgenus
# infragenericEpithet
# specificEpithet
# infraspecificEpithet
# cultivarEpithet
# taxonRank
# verbatimTaxonRank
# vernacularName
# nomenclaturalCode
# taxonomicStatus
# nomenclaturalStatus
# taxonRemarks
# datasetKey
# publishingCountry
# lastInterpreted
# elevation
# elevationAccuracy
# depth
# depthAccuracy
# distanceFromCentroidInMeters
# issue
# mediaType
# hasCoordinate
# hasGeospatialIssues
# taxonKey
# acceptedTaxonKey
# kingdomKey
# phylumKey
# classKey
# orderKey
# familyKey
# genusKey
# subgenusKey
# speciesKey
# species
# acceptedScientificName
# verbatimScientificName
# typifiedName
# protocol
# lastParsed
# lastCrawled
# repatriated
# relativeOrganismQuantity
# projectId
# level0Gid
# level0Name
# level1Gid
# level1Name
# level2Gid
# level2Name
# level3Gid
# level3Name
# iucnRedListCategory
# eventType
# quantidade_colunas_totalmente_nan: 145

# %%
len(lista_label_colunas_totalmente_nan)
# Out:
# 145

# %% [markdown]
# 145 de 212 colunas nao possuem dado nenhum registrado

# %%
dados_sem_colunas_totalmente_nan = dados.drop(lista_label_colunas_totalmente_nan, axis = 1)

# %%
dados_sem_colunas_totalmente_nan
# Out:
#          gbifID                                       accessRights  \
# 0    2365686427  Creative Commons Attribution Non Commercial (C...
# 1    2365686418  Creative Commons Attribution Non Commercial (C...
# 2    2365686416  Creative Commons Attribution Non Commercial (C...
# 3    2365686414  Creative Commons Attribution Non Commercial (C...
# 4    2365686412  Creative Commons Attribution Non Commercial (C...
# ..          ...                                                ...
# 887  1438492475  Creative Commons Attribution Non Commercial (C...
# 888  1438492474  Creative Commons Attribution Non Commercial (C...
# 889  1438492473  Creative Commons Attribution Non Commercial (C...
# 890  1438492472  Creative Commons Attribution Non Commercial (C...
# 891  1438492471  Creative Commons Attribution Non Commercial (C...
#
#           license                         rightsHolder institutionCode  \
# 0    CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 1    CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 2    CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 3    CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 4    CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# ..            ...                                  ...             ...
# 887  CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 888  CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 889  CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 890  CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
# 891  CC_BY_NC_4_0  Museu Paraense Emílio Goeldi (MPEG)            MPEG
#
#     collectionCode       basisOfRecord     occurrenceID    catalogNumber  \
# 0              ANL  PRESERVED_SPECIMEN  MPEG.ANL 001101  MPEG.ANL 001101
# 1              ANL  PRESERVED_SPECIMEN  MPEG.ANL 001596  MPEG.ANL 001596
# 2              ANL  PRESERVED_SPECIMEN  MPEG.ANL 001635  MPEG.ANL 001635
# 3              ANL  PRESERVED_SPECIMEN  MPEG.ANL 001031  MPEG.ANL 001031
# 4              ANL  PRESERVED_SPECIMEN  MPEG.ANL 001036  MPEG.ANL 001036
# ..             ...                 ...              ...              ...
# 887            ANL  PRESERVED_SPECIMEN  MPEG.ANL 000009  MPEG.ANL 000009
# 888            ANL  PRESERVED_SPECIMEN  MPEG.ANL 000023  MPEG.ANL 000023
# 889            ANL  PRESERVED_SPECIMEN  MPEG.ANL 000019  MPEG.ANL 000019
# 890            ANL  PRESERVED_SPECIMEN  MPEG.ANL 000024  MPEG.ANL 000024
# 891            ANL  PRESERVED_SPECIMEN  MPEG.ANL 000010  MPEG.ANL 000010
#
#                                             recordedBy occurrenceStatus  \
# 0            Beckman, Ruana; Pena, José; Souza, Raíssa          PRESENT
# 1    Sousa, Sandriel; Hernández, Luis; Rousseau, Gu...          PRESENT
# 2        Sousa, Anny; Sousa, Sandriel; Hernández, Luis          PRESENT
# 3            Beckman, Ruana; Pena, José; Souza, Raíssa          PRESENT
# 4            Beckman, Ruana; Pena, José; Souza, Raíssa          PRESENT
# ..                                                 ...              ...
# 887                            Lavelle, P. ; ,  Equipe          PRESENT
# 888                            Lavelle, P. ; ,  Equipe          PRESENT
# 889                            Lavelle, P. ; ,  Equipe          PRESENT
# 890                            Lavelle, P. ; ,  Equipe          PRESENT
# 891                            Lavelle, P. ; ,  Equipe          PRESENT
#
#     preparations            eventDate    year  month   day eventRemarks  \
# 0     Etanol - 3  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN
# 1     Etanol - 1  2018-08-15T00:00:00  2018.0    8.0  15.0          NaN
# 2     Etanol - 1  2019-02-12T00:00:00  2019.0    2.0  12.0          NaN
# 3     Etanol - 1  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN
# 4    Etanol - 17  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN
# ..           ...                  ...     ...    ...   ...          ...
# 887   Etanol - 7  2008-06-04T00:00:00  2008.0    6.0   4.0          NaN
# 888   Etanol - 2  2008-06-04T00:00:00  2008.0    6.0   4.0          NaN
# 889   Etanol - 2  2008-06-04T00:00:00  2008.0    6.0   4.0          NaN
# 890   Etanol - 1  2008-06-04T00:00:00  2008.0    6.0   4.0          NaN
# 891   Etanol - 4  2008-06-04T00:00:00  2008.0    6.0   4.0          NaN
#
#         higherGeography      continent countryCode stateProvince  \
# 0           Pará, Belém            NaN          BR          Pará
# 1    Maranhão, São Luís  SOUTH_AMERICA          BR      Maranhão
# 2      Maranhão, Caxias  SOUTH_AMERICA          BR      Maranhão
# 3           Pará, Belém            NaN          BR          Pará
# 4           Pará, Belém            NaN          BR          Pará
# ..                  ...            ...         ...           ...
# 887  Pará, Nova Ipixuna  SOUTH_AMERICA          BR          Pará
# 888  Pará, Nova Ipixuna  SOUTH_AMERICA          BR          Pará
# 889  Pará, Nova Ipixuna  SOUTH_AMERICA          BR          Pará
# 890  Pará, Nova Ipixuna  SOUTH_AMERICA          BR          Pará
# 891  Pará, Nova Ipixuna  SOUTH_AMERICA          BR          Pará
#
#            county                    locality  decimalLatitude  \
# 0           Belém                     Mocambo         1.440694
# 1        São Luís              Fazenda Escola        -4.587222
# 2          Caxias        Santa Tereza Village        -4.899722
# 3           Belém                     Mocambo         1.440694
# 4           Belém                     Mocambo         1.440694
# ..            ...                         ...              ...
# 887  Nova Ipixuna     Maçaranduba-Lote Galbão        -4.806111
# 888  Nova Ipixuna  Maçaranduba-Lote Zé Rondon        -4.806111
# 889  Nova Ipixuna   Maçaranduba-Lote Jurandir        -4.806111
# 890  Nova Ipixuna   Maçaranduba-Lote Jurandir        -4.806111
# 891  Nova Ipixuna       Maçaranduba-Lote Geni        -4.806111
#
#      decimalLongitude typeStatus                          scientificName  \
# 0          -48.411250        NaN                             Pontoscolex
# 1          -44.208611        NaN           Liodrilus mendesi Righi, 1994
# 2          -43.470833        NaN           Liodrilus mendesi Righi, 1994
# 3          -48.411250        NaN                             Pontoscolex
# 4          -48.411250        NaN                             Pontoscolex
# ..                ...        ...                                     ...
# 887        -49.317778        NaN  Pontoscolex corethrurus (Muller, 1856)
# 888        -49.317778        NaN  Pontoscolex corethrurus (Muller, 1856)
# 889        -49.317778        NaN  Pontoscolex corethrurus (Muller, 1856)
# 890        -49.317778        NaN  Pontoscolex corethrurus (Muller, 1856)
# 891        -49.317778        NaN  Pontoscolex corethrurus (Muller, 1856)
#
#       kingdom    phylum       class             order            family  \
# 0    Animalia  Annelida  Clitellata       Haplotaxida  Glossoscolecidae
# 1    Animalia  Annelida  Clitellata               NaN               NaN
# 2    Animalia  Annelida  Clitellata               NaN               NaN
# 3    Animalia  Annelida  Clitellata       Haplotaxida  Glossoscolecidae
# 4    Animalia  Annelida  Clitellata       Haplotaxida  Glossoscolecidae
# ..        ...       ...         ...               ...               ...
# 887  Animalia  Annelida  Clitellata  Crassiclitellata     Rhinodrilidae
# 888  Animalia  Annelida  Clitellata  Crassiclitellata     Rhinodrilidae
# 889  Animalia  Annelida  Clitellata  Crassiclitellata     Rhinodrilidae
# 890  Animalia  Annelida  Clitellata  Crassiclitellata     Rhinodrilidae
# 891  Animalia  Annelida  Clitellata  Crassiclitellata     Rhinodrilidae
#
#            genus  genericName specificEpithet infraspecificEpithet taxonRank  \
# 0    Pontoscolex  Pontoscolex             NaN                  NaN     GENUS
# 1      Liodrilus    Liodrilus         mendesi                  NaN   SPECIES
# 2      Liodrilus    Liodrilus         mendesi                  NaN   SPECIES
# 3    Pontoscolex  Pontoscolex             NaN                  NaN     GENUS
# 4    Pontoscolex  Pontoscolex             NaN                  NaN     GENUS
# ..           ...          ...             ...                  ...       ...
# 887  Pontoscolex  Pontoscolex     corethrurus                  NaN   SPECIES
# 888  Pontoscolex  Pontoscolex     corethrurus                  NaN   SPECIES
# 889  Pontoscolex  Pontoscolex     corethrurus                  NaN   SPECIES
# 890  Pontoscolex  Pontoscolex     corethrurus                  NaN   SPECIES
# 891  Pontoscolex  Pontoscolex     corethrurus                  NaN   SPECIES
#
#     taxonomicStatus                            datasetKey publishingCountry  \
# 0          DOUBTFUL  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 1          ACCEPTED  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 2          ACCEPTED  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 3          DOUBTFUL  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 4          DOUBTFUL  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# ..              ...                                   ...               ...
# 887        ACCEPTED  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 888        ACCEPTED  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 889        ACCEPTED  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 890        ACCEPTED  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
# 891        ACCEPTED  9c48ee0b-404a-4c84-9af0-946eef39ddca                BR
#
#               lastInterpreted  \
# 0    2023-09-07T09:19:05.952Z
# 1    2023-09-07T09:19:05.949Z
# 2    2023-09-07T09:19:05.937Z
# 3    2023-09-07T09:19:05.946Z
# 4    2023-09-07T09:19:05.946Z
# ..                        ...
# 887  2023-09-07T09:19:05.950Z
# 888  2023-09-07T09:19:05.952Z
# 889  2023-09-07T09:19:05.949Z
# 890  2023-09-07T09:19:05.952Z
# 891  2023-09-07T09:19:05.950Z
#
#                                                  issue  hasCoordinate  \
# 0    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 1    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 2    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 3    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 4    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# ..                                                 ...            ...
# 887  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 888  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 889  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 890  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 891  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
#
#      hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                   True   2308740         2308740.0           1       42.0
# 1                  False   9512479         9512479.0           1       42.0
# 2                  False   9512479         9512479.0           1       42.0
# 3                   True   2308740         2308740.0           1       42.0
# 4                   True   2308740         2308740.0           1       42.0
# ..                   ...       ...               ...         ...        ...
# 887                False   2308741         2308741.0           1       42.0
# 888                False   2308741         2308741.0           1       42.0
# 889                False   2308741         2308741.0           1       42.0
# 890                False   2308741         2308741.0           1       42.0
# 891                False   2308741         2308741.0           1       42.0
#
#      classKey   orderKey  familyKey    genusKey  speciesKey  \
# 0       255.0      472.0     3567.0   2308740.0         NaN
# 1       255.0        NaN        NaN   4813824.0   9512479.0
# 2       255.0        NaN        NaN   4813824.0   9512479.0
# 3       255.0      472.0     3567.0   2308740.0         NaN
# 4       255.0      472.0     3567.0   2308740.0         NaN
# ..        ...        ...        ...         ...         ...
# 887     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 888     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 889     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 890     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 891     255.0  5958860.0  9272891.0  10943108.0   2308741.0
#
#                      species                  acceptedScientificName  \
# 0                        NaN                             Pontoscolex
# 1          Liodrilus mendesi           Liodrilus mendesi Righi, 1994
# 2          Liodrilus mendesi           Liodrilus mendesi Righi, 1994
# 3                        NaN                             Pontoscolex
# 4                        NaN                             Pontoscolex
# ..                       ...                                     ...
# 887  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 888  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 889  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 890  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 891  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
#
#       verbatimScientificName protocol                lastParsed  \
# 0    Pontoscolex Corethrurus      EML  2023-09-07T09:19:05.952Z
# 1          Liodrilus mendesi      EML  2023-09-07T09:19:05.949Z
# 2          Liodrilus mendesi      EML  2023-09-07T09:19:05.937Z
# 3    Pontoscolex Corethrurus      EML  2023-09-07T09:19:05.946Z
# 4    Pontoscolex Corethrurus      EML  2023-09-07T09:19:05.946Z
# ..                       ...      ...                       ...
# 887  Pontoscolex corethrurus      EML  2023-09-07T09:19:05.950Z
# 888  Pontoscolex corethrurus      EML  2023-09-07T09:19:05.952Z
# 889  Pontoscolex corethrurus      EML  2023-09-07T09:19:05.949Z
# 890  Pontoscolex corethrurus      EML  2023-09-07T09:19:05.952Z
# 891  Pontoscolex corethrurus      EML  2023-09-07T09:19:05.950Z
#
#                   lastCrawled repatriated level0Gid level0Name level1Gid  \
# 0    2023-01-07T11:25:05.817Z       false      None       None      None
# 1    2023-01-07T11:25:05.817Z       false       BRA     Brazil  BRA.10_1
# 2    2023-01-07T11:25:05.817Z       false       BRA     Brazil  BRA.10_1
# 3    2023-01-07T11:25:05.817Z       false      None       None      None
# 4    2023-01-07T11:25:05.817Z       false      None       None      None
# ..                        ...         ...       ...        ...       ...
# 887  2023-01-07T11:25:05.817Z       false       BRA     Brazil  BRA.14_1
# 888  2023-01-07T11:25:05.817Z       false       BRA     Brazil  BRA.14_1
# 889  2023-01-07T11:25:05.817Z       false       BRA     Brazil  BRA.14_1
# 890  2023-01-07T11:25:05.817Z       false       BRA     Brazil  BRA.14_1
# 891  2023-01-07T11:25:05.817Z       false       BRA     Brazil  BRA.14_1
#
#     level1Name    level2Gid    level2Name iucnRedListCategory
# 0         None         None          None                None
# 1     Maranhão  BRA.10.59_2          Codó                  NE
# 2     Maranhão  BRA.10.52_2        Caxias                  NE
# 3         None         None          None                None
# 4         None         None          None                None
# ..         ...          ...           ...                 ...
# 887       Pará  BRA.14.78_2  Nova Ipixuna                  NE
# 888       Pará  BRA.14.78_2  Nova Ipixuna                  NE
# 889       Pará  BRA.14.78_2  Nova Ipixuna                  NE
# 890       Pará  BRA.14.78_2  Nova Ipixuna                  NE
# 891       Pará  BRA.14.78_2  Nova Ipixuna                  NE
#
# [892 rows x 67 columns]

# %%
dados_sem_colunas_totalmente_nan.isna().sum()
# Out:
# gbifID                   0
# accessRights             0
# license                  0
# rightsHolder             0
# institutionCode          0
#                       ...
# level1Gid              288
# level1Name             288
# level2Gid              288
# level2Name             288
# iucnRedListCategory    529
# Length: 67, dtype: int64

# %% [markdown]
# Agora lidar com valores fixos. Depois lidar com os demais nans

# %% [markdown]
# Pegar todas as colunas que possuem valor fixo. Guardar o label de cada coluna como uma chave de um dicionario e o valor fixo de dada coluna como o valor associado a chave da label correspondente.

# %%
dicionario_colunas_valores_fixo = {}

# %%
i = 0

for column in dados_sem_colunas_totalmente_nan.columns:

  if len(dados_sem_colunas_totalmente_nan[column].unique()) == 1:

    i += 1

    print(f'Label coluna: {column}')

    print(f'Valor da coluna: {dados_sem_colunas_totalmente_nan[column][0]}\n')

    dicionario_colunas_valores_fixo[column] = [pd.NA, dados_sem_colunas_totalmente_nan[column][0]]

print(i)
# Out:
# Label coluna: accessRights
# Valor da coluna: Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License.
#
# Label coluna: license
# Valor da coluna: CC_BY_NC_4_0
#
# Label coluna: rightsHolder
# Valor da coluna: Museu Paraense Emílio Goeldi (MPEG)
#
# Label coluna: institutionCode
# Valor da coluna: MPEG
#
# Label coluna: collectionCode
# Valor da coluna: ANL
#
# Label coluna: basisOfRecord
# Valor da coluna: PRESERVED_SPECIMEN
#
# Label coluna: occurrenceStatus
# Valor da coluna: PRESENT
#
# Label coluna: datasetKey
# Valor da coluna: 9c48ee0b-404a-4c84-9af0-946eef39ddca
#
# Label coluna: publishingCountry
# Valor da coluna: BR
#
# Label coluna: protocol
# Valor da coluna: EML
#
# Label coluna: lastCrawled
# Valor da coluna: 2023-01-07T11:25:05.817Z
#
# 11

# %%
len(dicionario_colunas_valores_fixo)
# Out:
# 11

# %%
dicionario_colunas_valores_fixo
# Out:
# {'accessRights': [<NA>,
#   'Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License.'],
#  'license': [<NA>, 'CC_BY_NC_4_0'],
#  'rightsHolder': [<NA>, 'Museu Paraense Emílio Goeldi (MPEG)'],
#  'institutionCode': [<NA>, 'MPEG'],
#  'collectionCode': [<NA>, 'ANL'],
#  'basisOfRecord': [<NA>, 'PRESERVED_SPECIMEN'],
#  'occurrenceStatus': [<NA>, 'PRESENT'],
#  'datasetKey': [<NA>, '9c48ee0b-404a-4c84-9af0-946eef39ddca'],
#  'publishingCountry': [<NA>, 'BR'],
#  'protocol': [<NA>, 'EML'],
#  'lastCrawled': [<NA>, '2023-01-07T11:25:05.817Z']}

# %%
dicionario_colunas_valores_fixo.keys()
# Out:
# dict_keys(['accessRights', 'license', 'rightsHolder', 'institutionCode', 'collectionCode', 'basisOfRecord', 'occurrenceStatus', 'datasetKey', 'publishingCountry', 'protocol', 'lastCrawled'])

# %%
dados_sem_nan_e_fixos = dados_sem_colunas_totalmente_nan.drop(dicionario_colunas_valores_fixo.keys(), axis = 1)

# %%
dados_sem_nan_e_fixos.head()
# Out:
#        gbifID     occurrenceID    catalogNumber  \
# 0  2365686427  MPEG.ANL 001101  MPEG.ANL 001101
# 1  2365686418  MPEG.ANL 001596  MPEG.ANL 001596
# 2  2365686416  MPEG.ANL 001635  MPEG.ANL 001635
# 3  2365686414  MPEG.ANL 001031  MPEG.ANL 001031
# 4  2365686412  MPEG.ANL 001036  MPEG.ANL 001036
#
#                                           recordedBy preparations  \
# 0          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
# 1  Sousa, Sandriel; Hernández, Luis; Rousseau, Gu...   Etanol - 1
# 2      Sousa, Anny; Sousa, Sandriel; Hernández, Luis   Etanol - 1
# 3          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 1
# 4          Beckman, Ruana; Pena, José; Souza, Raíssa  Etanol - 17
#
#              eventDate    year  month   day eventRemarks     higherGeography  \
# 0  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 1  2018-08-15T00:00:00  2018.0    8.0  15.0          NaN  Maranhão, São Luís
# 2  2019-02-12T00:00:00  2019.0    2.0  12.0          NaN    Maranhão, Caxias
# 3  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 4  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
#
#        continent countryCode stateProvince    county              locality  \
# 0            NaN          BR          Pará     Belém               Mocambo
# 1  SOUTH_AMERICA          BR      Maranhão  São Luís        Fazenda Escola
# 2  SOUTH_AMERICA          BR      Maranhão    Caxias  Santa Tereza Village
# 3            NaN          BR          Pará     Belém               Mocambo
# 4            NaN          BR          Pará     Belém               Mocambo
#
#    decimalLatitude  decimalLongitude typeStatus  \
# 0         1.440694        -48.411250        NaN
# 1        -4.587222        -44.208611        NaN
# 2        -4.899722        -43.470833        NaN
# 3         1.440694        -48.411250        NaN
# 4         1.440694        -48.411250        NaN
#
#                   scientificName   kingdom    phylum       class        order  \
# 0                    Pontoscolex  Animalia  Annelida  Clitellata  Haplotaxida
# 1  Liodrilus mendesi Righi, 1994  Animalia  Annelida  Clitellata          NaN
# 2  Liodrilus mendesi Righi, 1994  Animalia  Annelida  Clitellata          NaN
# 3                    Pontoscolex  Animalia  Annelida  Clitellata  Haplotaxida
# 4                    Pontoscolex  Animalia  Annelida  Clitellata  Haplotaxida
#
#              family        genus  genericName specificEpithet  \
# 0  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 1               NaN    Liodrilus    Liodrilus         mendesi
# 2               NaN    Liodrilus    Liodrilus         mendesi
# 3  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 4  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
#
#   infraspecificEpithet taxonRank taxonomicStatus           lastInterpreted  \
# 0                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.952Z
# 1                  NaN   SPECIES        ACCEPTED  2023-09-07T09:19:05.949Z
# 2                  NaN   SPECIES        ACCEPTED  2023-09-07T09:19:05.937Z
# 3                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.946Z
# 4                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.946Z
#
#                                                issue  hasCoordinate  \
# 0  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 1  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 2  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 4  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
#
#    hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                 True   2308740         2308740.0           1       42.0
# 1                False   9512479         9512479.0           1       42.0
# 2                False   9512479         9512479.0           1       42.0
# 3                 True   2308740         2308740.0           1       42.0
# 4                 True   2308740         2308740.0           1       42.0
#
#    classKey  orderKey  familyKey   genusKey  speciesKey            species  \
# 0     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 1     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 2     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 3     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 4     255.0     472.0     3567.0  2308740.0         NaN                NaN
#
#           acceptedScientificName   verbatimScientificName  \
# 0                    Pontoscolex  Pontoscolex Corethrurus
# 1  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 2  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 3                    Pontoscolex  Pontoscolex Corethrurus
# 4                    Pontoscolex  Pontoscolex Corethrurus
#
#                  lastParsed repatriated level0Gid level0Name level1Gid  \
# 0  2023-09-07T09:19:05.952Z       false      None       None      None
# 1  2023-09-07T09:19:05.949Z       false       BRA     Brazil  BRA.10_1
# 2  2023-09-07T09:19:05.937Z       false       BRA     Brazil  BRA.10_1
# 3  2023-09-07T09:19:05.946Z       false      None       None      None
# 4  2023-09-07T09:19:05.946Z       false      None       None      None
#
#   level1Name    level2Gid level2Name iucnRedListCategory
# 0       None         None       None                None
# 1   Maranhão  BRA.10.59_2       Codó                  NE
# 2   Maranhão  BRA.10.52_2     Caxias                  NE
# 3       None         None       None                None
# 4       None         None       None                None

# %% [markdown]
# Possiveis tratamentos especificos.

# %%
for column in dados_sem_nan_e_fixos:

  if dados_sem_nan_e_fixos[column].isna().sum() > 0:

    print(column)
# Out:
# recordedBy
# preparations
# eventDate
# year
# month
# day
# eventRemarks
# higherGeography
# continent
# countryCode
# stateProvince
# county
# locality
# decimalLatitude
# decimalLongitude
# typeStatus
# phylum
# class
# order
# family
# genus
# genericName
# specificEpithet
# infraspecificEpithet
# taxonomicStatus
# acceptedTaxonKey
# phylumKey
# classKey
# orderKey
# familyKey
# genusKey
# speciesKey
# species
# acceptedScientificName
# verbatimScientificName
# repatriated
# level0Gid
# level0Name
# level1Gid
# level1Name
# level2Gid
# level2Name
# iucnRedListCategory

# %% [markdown]
# A

# %% [markdown]
# Essas colunas sao explicadas de acordo com a estrutura do gbif, por isso nao tem do dataset em si

# %%
len(dados_sem_nan_e_fixos[dados_sem_nan_e_fixos['eventDate'].isna() & ~dados_sem_nan_e_fixos['day'].isna()])
# Out:
# 0

# %%
for valor_campo_data in ['year', 'month', 'day']:


  if len(dados_sem_nan_e_fixos[dados_sem_nan_e_fixos['eventDate'].isna() & ~dados_sem_nan_e_fixos[valor_campo_data].isna()]) > 0:

    print(valor_campo_data)

# %% [markdown]
# Nao tem como definir eventDate a partir das colunas year, month e/ou year

# %%
for valor_campo_data in ['year', 'month', 'day']: #sei que é repeticao. Mas separei para deixar mais claro e facilitar a segmentacao da analise


  if len(dados_sem_nan_e_fixos[dados_sem_nan_e_fixos[valor_campo_data].isna() & ~dados_sem_nan_e_fixos['eventDate'].isna()]) > 0:

    print(valor_campo_data)
# Out:
# month
# day

# %% [markdown]
# Nesse caso, não faz sentido preencher a coluna eventDate com valores arbitrários de ano

# %%
dados_sem_nan_e_fixos[dados_sem_nan_e_fixos['higherGeography'].isna()]
# Out:
#          gbifID     occurrenceID    catalogNumber  \
# 145  2365686000  MPEG.ANL 001044  MPEG.ANL 001044
#
#                                     recordedBy preparations  \
# 145  Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
#
#                eventDate    year  month   day eventRemarks higherGeography  \
# 145  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN             NaN
#
#     continent countryCode stateProvince county locality  decimalLatitude  \
# 145       NaN         NaN           NaN    NaN      NaN              NaN
#
#      decimalLongitude typeStatus scientificName   kingdom    phylum  \
# 145               NaN        NaN    Pontoscolex  Animalia  Annelida
#
#           class        order            family        genus  genericName  \
# 145  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex
#
#     specificEpithet infraspecificEpithet taxonRank taxonomicStatus  \
# 145             NaN                  NaN     GENUS        DOUBTFUL
#
#               lastInterpreted                                          issue  \
# 145  2023-09-07T09:19:05.946Z  COLLECTION_MATCH_NONE;INSTITUTION_MATCH_FUZZY
#
#      hasCoordinate  hasGeospatialIssues  taxonKey  acceptedTaxonKey  \
# 145          False                False   2308740         2308740.0
#
#      kingdomKey  phylumKey  classKey  orderKey  familyKey   genusKey  \
# 145           1       42.0     255.0     472.0     3567.0  2308740.0
#
#      speciesKey species acceptedScientificName verbatimScientificName  \
# 145         NaN     NaN            Pontoscolex            Pontoscolex
#
#                    lastParsed repatriated level0Gid level0Name level1Gid  \
# 145  2023-09-07T09:19:05.946Z        None      None       None      None
#
#     level1Name level2Gid level2Name iucnRedListCategory
# 145       None      None       None                None

# %% [markdown]
# Higher geography é a concatenação das colunas stateProvince e county. Nesse único registro nan para higherGeography, essas duas outras colunas tambem estao faltantes

# %%
dados_sem_nan_e_fixos[dados_sem_nan_e_fixos['continent'].isna()].head()
# Out:
#        gbifID     occurrenceID    catalogNumber  \
# 0  2365686427  MPEG.ANL 001101  MPEG.ANL 001101
# 3  2365686414  MPEG.ANL 001031  MPEG.ANL 001031
# 4  2365686412  MPEG.ANL 001036  MPEG.ANL 001036
# 8  2365686406  MPEG.ANL 001090  MPEG.ANL 001090
# 9  2365686405  MPEG.ANL 001083  MPEG.ANL 001083
#
#                                   recordedBy preparations  \
# 0  Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
# 3  Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 1
# 4  Beckman, Ruana; Pena, José; Souza, Raíssa  Etanol - 17
# 8  Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 1
# 9  Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
#
#              eventDate    year  month   day eventRemarks higherGeography  \
# 0  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN     Pará, Belém
# 3  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN     Pará, Belém
# 4  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN     Pará, Belém
# 8  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN     Pará, Belém
# 9  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN     Pará, Belém
#
#   continent countryCode stateProvince county locality  decimalLatitude  \
# 0       NaN          BR          Pará  Belém  Mocambo         1.440694
# 3       NaN          BR          Pará  Belém  Mocambo         1.440694
# 4       NaN          BR          Pará  Belém  Mocambo         1.440694
# 8       NaN          BR          Pará  Belém  Mocambo         1.440694
# 9       NaN          BR          Pará  Belém  Mocambo         1.440694
#
#    decimalLongitude typeStatus scientificName   kingdom    phylum       class  \
# 0         -48.41125        NaN    Pontoscolex  Animalia  Annelida  Clitellata
# 3         -48.41125        NaN    Pontoscolex  Animalia  Annelida  Clitellata
# 4         -48.41125        NaN    Pontoscolex  Animalia  Annelida  Clitellata
# 8         -48.41125        NaN    Pontoscolex  Animalia  Annelida  Clitellata
# 9         -48.41125        NaN    Pontoscolex  Animalia  Annelida  Clitellata
#
#          order            family        genus  genericName specificEpithet  \
# 0  Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 3  Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 4  Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 8  Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 9  Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
#
#   infraspecificEpithet taxonRank taxonomicStatus           lastInterpreted  \
# 0                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.952Z
# 3                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.946Z
# 4                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.946Z
# 8                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.947Z
# 9                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.945Z
#
#                                                issue  hasCoordinate  \
# 0  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 4  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 8  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 9  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
#
#    hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                 True   2308740         2308740.0           1       42.0
# 3                 True   2308740         2308740.0           1       42.0
# 4                 True   2308740         2308740.0           1       42.0
# 8                 True   2308740         2308740.0           1       42.0
# 9                 True   2308740         2308740.0           1       42.0
#
#    classKey  orderKey  familyKey   genusKey  speciesKey species  \
# 0     255.0     472.0     3567.0  2308740.0         NaN     NaN
# 3     255.0     472.0     3567.0  2308740.0         NaN     NaN
# 4     255.0     472.0     3567.0  2308740.0         NaN     NaN
# 8     255.0     472.0     3567.0  2308740.0         NaN     NaN
# 9     255.0     472.0     3567.0  2308740.0         NaN     NaN
#
#   acceptedScientificName   verbatimScientificName                lastParsed  \
# 0            Pontoscolex  Pontoscolex Corethrurus  2023-09-07T09:19:05.952Z
# 3            Pontoscolex  Pontoscolex Corethrurus  2023-09-07T09:19:05.946Z
# 4            Pontoscolex  Pontoscolex Corethrurus  2023-09-07T09:19:05.946Z
# 8            Pontoscolex  Pontoscolex Corethrurus  2023-09-07T09:19:05.947Z
# 9            Pontoscolex  Pontoscolex Corethrurus  2023-09-07T09:19:05.945Z
#
#   repatriated level0Gid level0Name level1Gid level1Name level2Gid level2Name  \
# 0       false      None       None      None       None      None       None
# 3       false      None       None      None       None      None       None
# 4       false      None       None      None       None      None       None
# 8       false      None       None      None       None      None       None
# 9       false      None       None      None       None      None       None
#
#   iucnRedListCategory
# 0                None
# 3                None
# 4                None
# 8                None
# 9                None

# %%
def preencher_continent(row): #Utilizando pares já definidos no dataframe de continente x countryCode, preencher os registros que possuem countryCode preenchido mas continent nao

    if pd.isna(row['continent']):

        valores_conhecidos = dados_sem_nan_e_fixos[dados_sem_nan_e_fixos['countryCode'] == row['countryCode']]['continent'].dropna()

        if not valores_conhecidos.empty:

            return valores_conhecidos.iloc[0]

        else:

            return pd.NA

    else:

        return row['continent']


dados_sem_nan_e_fixos['continent'] = dados_sem_nan_e_fixos.apply(preencher_continent, axis=1)

# %%
dados_sem_nan_e_fixos['continent'] = dados_sem_nan_e_fixos.apply(preencher_continent, axis=1)

# %%
dados_sem_nan_e_fixos.head()
# Out:
#        gbifID     occurrenceID    catalogNumber  \
# 0  2365686427  MPEG.ANL 001101  MPEG.ANL 001101
# 1  2365686418  MPEG.ANL 001596  MPEG.ANL 001596
# 2  2365686416  MPEG.ANL 001635  MPEG.ANL 001635
# 3  2365686414  MPEG.ANL 001031  MPEG.ANL 001031
# 4  2365686412  MPEG.ANL 001036  MPEG.ANL 001036
#
#                                           recordedBy preparations  \
# 0          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
# 1  Sousa, Sandriel; Hernández, Luis; Rousseau, Gu...   Etanol - 1
# 2      Sousa, Anny; Sousa, Sandriel; Hernández, Luis   Etanol - 1
# 3          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 1
# 4          Beckman, Ruana; Pena, José; Souza, Raíssa  Etanol - 17
#
#              eventDate    year  month   day eventRemarks     higherGeography  \
# 0  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 1  2018-08-15T00:00:00  2018.0    8.0  15.0          NaN  Maranhão, São Luís
# 2  2019-02-12T00:00:00  2019.0    2.0  12.0          NaN    Maranhão, Caxias
# 3  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 4  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
#
#        continent countryCode stateProvince    county              locality  \
# 0  SOUTH_AMERICA          BR          Pará     Belém               Mocambo
# 1  SOUTH_AMERICA          BR      Maranhão  São Luís        Fazenda Escola
# 2  SOUTH_AMERICA          BR      Maranhão    Caxias  Santa Tereza Village
# 3  SOUTH_AMERICA          BR          Pará     Belém               Mocambo
# 4  SOUTH_AMERICA          BR          Pará     Belém               Mocambo
#
#    decimalLatitude  decimalLongitude typeStatus  \
# 0         1.440694        -48.411250        NaN
# 1        -4.587222        -44.208611        NaN
# 2        -4.899722        -43.470833        NaN
# 3         1.440694        -48.411250        NaN
# 4         1.440694        -48.411250        NaN
#
#                   scientificName   kingdom    phylum       class        order  \
# 0                    Pontoscolex  Animalia  Annelida  Clitellata  Haplotaxida
# 1  Liodrilus mendesi Righi, 1994  Animalia  Annelida  Clitellata          NaN
# 2  Liodrilus mendesi Righi, 1994  Animalia  Annelida  Clitellata          NaN
# 3                    Pontoscolex  Animalia  Annelida  Clitellata  Haplotaxida
# 4                    Pontoscolex  Animalia  Annelida  Clitellata  Haplotaxida
#
#              family        genus  genericName specificEpithet  \
# 0  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 1               NaN    Liodrilus    Liodrilus         mendesi
# 2               NaN    Liodrilus    Liodrilus         mendesi
# 3  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
# 4  Glossoscolecidae  Pontoscolex  Pontoscolex             NaN
#
#   infraspecificEpithet taxonRank taxonomicStatus           lastInterpreted  \
# 0                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.952Z
# 1                  NaN   SPECIES        ACCEPTED  2023-09-07T09:19:05.949Z
# 2                  NaN   SPECIES        ACCEPTED  2023-09-07T09:19:05.937Z
# 3                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.946Z
# 4                  NaN     GENUS        DOUBTFUL  2023-09-07T09:19:05.946Z
#
#                                                issue  hasCoordinate  \
# 0  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 1  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 2  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 4  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
#
#    hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                 True   2308740         2308740.0           1       42.0
# 1                False   9512479         9512479.0           1       42.0
# 2                False   9512479         9512479.0           1       42.0
# 3                 True   2308740         2308740.0           1       42.0
# 4                 True   2308740         2308740.0           1       42.0
#
#    classKey  orderKey  familyKey   genusKey  speciesKey            species  \
# 0     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 1     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 2     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 3     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 4     255.0     472.0     3567.0  2308740.0         NaN                NaN
#
#           acceptedScientificName   verbatimScientificName  \
# 0                    Pontoscolex  Pontoscolex Corethrurus
# 1  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 2  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 3                    Pontoscolex  Pontoscolex Corethrurus
# 4                    Pontoscolex  Pontoscolex Corethrurus
#
#                  lastParsed repatriated level0Gid level0Name level1Gid  \
# 0  2023-09-07T09:19:05.952Z       false      None       None      None
# 1  2023-09-07T09:19:05.949Z       false       BRA     Brazil  BRA.10_1
# 2  2023-09-07T09:19:05.937Z       false       BRA     Brazil  BRA.10_1
# 3  2023-09-07T09:19:05.946Z       false      None       None      None
# 4  2023-09-07T09:19:05.946Z       false      None       None      None
#
#   level1Name    level2Gid level2Name iucnRedListCategory
# 0       None         None       None                None
# 1   Maranhão  BRA.10.59_2       Codó                  NE
# 2   Maranhão  BRA.10.52_2     Caxias                  NE
# 3       None         None       None                None
# 4       None         None       None                None

# %%
dados_sem_nan_e_fixos['continent'].isna().sum()
# Out:
# 1

# %%
dados_sem_nan_e_fixos[dados_sem_nan_e_fixos['continent'].isna()]
# Out:
#          gbifID     occurrenceID    catalogNumber  \
# 145  2365686000  MPEG.ANL 001044  MPEG.ANL 001044
#
#                                     recordedBy preparations  \
# 145  Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
#
#                eventDate    year  month   day eventRemarks higherGeography  \
# 145  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN             NaN
#
#     continent countryCode stateProvince county locality  decimalLatitude  \
# 145      <NA>         NaN           NaN    NaN      NaN              NaN
#
#      decimalLongitude typeStatus scientificName   kingdom    phylum  \
# 145               NaN        NaN    Pontoscolex  Animalia  Annelida
#
#           class        order            family        genus  genericName  \
# 145  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex
#
#     specificEpithet infraspecificEpithet taxonRank taxonomicStatus  \
# 145             NaN                  NaN     GENUS        DOUBTFUL
#
#               lastInterpreted                                          issue  \
# 145  2023-09-07T09:19:05.946Z  COLLECTION_MATCH_NONE;INSTITUTION_MATCH_FUZZY
#
#      hasCoordinate  hasGeospatialIssues  taxonKey  acceptedTaxonKey  \
# 145          False                False   2308740         2308740.0
#
#      kingdomKey  phylumKey  classKey  orderKey  familyKey   genusKey  \
# 145           1       42.0     255.0     472.0     3567.0  2308740.0
#
#      speciesKey species acceptedScientificName verbatimScientificName  \
# 145         NaN     NaN            Pontoscolex            Pontoscolex
#
#                    lastParsed repatriated level0Gid level0Name level1Gid  \
# 145  2023-09-07T09:19:05.946Z        None      None       None      None
#
#     level1Name level2Gid level2Name iucnRedListCategory
# 145       None      None       None                None

# %%
len(dados_sem_nan_e_fixos['continent'].unique()) == 2
# Out:
# True

# %%
dicionario_colunas_valores_fixo['continent'] = [145, dados_sem_nan_e_fixos['continent'][0]]

# %%
dicionario_colunas_valores_fixo #talvez haja a necessidade de salvar os indexes em uma lista aninhada, aguardar pra ver se surge essa necessidade
# Out:
# {'accessRights': [<NA>,
#   'Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License.'],
#  'license': [<NA>, 'CC_BY_NC_4_0'],
#  'rightsHolder': [<NA>, 'Museu Paraense Emílio Goeldi (MPEG)'],
#  'institutionCode': [<NA>, 'MPEG'],
#  'collectionCode': [<NA>, 'ANL'],
#  'basisOfRecord': [<NA>, 'PRESERVED_SPECIMEN'],
#  'occurrenceStatus': [<NA>, 'PRESENT'],
#  'datasetKey': [<NA>, '9c48ee0b-404a-4c84-9af0-946eef39ddca'],
#  'publishingCountry': [<NA>, 'BR'],
#  'protocol': [<NA>, 'EML'],
#  'lastCrawled': [<NA>, '2023-01-07T11:25:05.817Z'],
#  'continent': [145, 'SOUTH_AMERICA']}

# %%
dados_sem_nan_e_fixos = dados_sem_nan_e_fixos.drop('continent', axis = 1)

# %%
dados_sem_nan_e_fixos.head()
# Out:
#        gbifID     occurrenceID    catalogNumber  \
# 0  2365686427  MPEG.ANL 001101  MPEG.ANL 001101
# 1  2365686418  MPEG.ANL 001596  MPEG.ANL 001596
# 2  2365686416  MPEG.ANL 001635  MPEG.ANL 001635
# 3  2365686414  MPEG.ANL 001031  MPEG.ANL 001031
# 4  2365686412  MPEG.ANL 001036  MPEG.ANL 001036
#
#                                           recordedBy preparations  \
# 0          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
# 1  Sousa, Sandriel; Hernández, Luis; Rousseau, Gu...   Etanol - 1
# 2      Sousa, Anny; Sousa, Sandriel; Hernández, Luis   Etanol - 1
# 3          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 1
# 4          Beckman, Ruana; Pena, José; Souza, Raíssa  Etanol - 17
#
#              eventDate    year  month   day eventRemarks     higherGeography  \
# 0  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 1  2018-08-15T00:00:00  2018.0    8.0  15.0          NaN  Maranhão, São Luís
# 2  2019-02-12T00:00:00  2019.0    2.0  12.0          NaN    Maranhão, Caxias
# 3  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 4  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
#
#   countryCode stateProvince    county              locality  decimalLatitude  \
# 0          BR          Pará     Belém               Mocambo         1.440694
# 1          BR      Maranhão  São Luís        Fazenda Escola        -4.587222
# 2          BR      Maranhão    Caxias  Santa Tereza Village        -4.899722
# 3          BR          Pará     Belém               Mocambo         1.440694
# 4          BR          Pará     Belém               Mocambo         1.440694
#
#    decimalLongitude typeStatus                 scientificName   kingdom  \
# 0        -48.411250        NaN                    Pontoscolex  Animalia
# 1        -44.208611        NaN  Liodrilus mendesi Righi, 1994  Animalia
# 2        -43.470833        NaN  Liodrilus mendesi Righi, 1994  Animalia
# 3        -48.411250        NaN                    Pontoscolex  Animalia
# 4        -48.411250        NaN                    Pontoscolex  Animalia
#
#      phylum       class        order            family        genus  \
# 0  Annelida  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex
# 1  Annelida  Clitellata          NaN               NaN    Liodrilus
# 2  Annelida  Clitellata          NaN               NaN    Liodrilus
# 3  Annelida  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex
# 4  Annelida  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex
#
#    genericName specificEpithet infraspecificEpithet taxonRank taxonomicStatus  \
# 0  Pontoscolex             NaN                  NaN     GENUS        DOUBTFUL
# 1    Liodrilus         mendesi                  NaN   SPECIES        ACCEPTED
# 2    Liodrilus         mendesi                  NaN   SPECIES        ACCEPTED
# 3  Pontoscolex             NaN                  NaN     GENUS        DOUBTFUL
# 4  Pontoscolex             NaN                  NaN     GENUS        DOUBTFUL
#
#             lastInterpreted  \
# 0  2023-09-07T09:19:05.952Z
# 1  2023-09-07T09:19:05.949Z
# 2  2023-09-07T09:19:05.937Z
# 3  2023-09-07T09:19:05.946Z
# 4  2023-09-07T09:19:05.946Z
#
#                                                issue  hasCoordinate  \
# 0  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 1  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 2  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 4  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
#
#    hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                 True   2308740         2308740.0           1       42.0
# 1                False   9512479         9512479.0           1       42.0
# 2                False   9512479         9512479.0           1       42.0
# 3                 True   2308740         2308740.0           1       42.0
# 4                 True   2308740         2308740.0           1       42.0
#
#    classKey  orderKey  familyKey   genusKey  speciesKey            species  \
# 0     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 1     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 2     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 3     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 4     255.0     472.0     3567.0  2308740.0         NaN                NaN
#
#           acceptedScientificName   verbatimScientificName  \
# 0                    Pontoscolex  Pontoscolex Corethrurus
# 1  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 2  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 3                    Pontoscolex  Pontoscolex Corethrurus
# 4                    Pontoscolex  Pontoscolex Corethrurus
#
#                  lastParsed repatriated level0Gid level0Name level1Gid  \
# 0  2023-09-07T09:19:05.952Z       false      None       None      None
# 1  2023-09-07T09:19:05.949Z       false       BRA     Brazil  BRA.10_1
# 2  2023-09-07T09:19:05.937Z       false       BRA     Brazil  BRA.10_1
# 3  2023-09-07T09:19:05.946Z       false      None       None      None
# 4  2023-09-07T09:19:05.946Z       false      None       None      None
#
#   level1Name    level2Gid level2Name iucnRedListCategory
# 0       None         None       None                None
# 1   Maranhão  BRA.10.59_2       Codó                  NE
# 2   Maranhão  BRA.10.52_2     Caxias                  NE
# 3       None         None       None                None
# 4       None         None       None                None

# %% [markdown]
# Como é apenas 1 registro de 892 que possui valor nan (e diferente do fixo) para essa coluna. Jogar essa coluna no dicionario. Dropar ela. Salvar o index do registro nan.

# %%
'''countryCode
stateProvince
county
higherGeography''' '''checar se posso compeltar um a partir do outro'''
# Out:
# 'countryCode\nstateProvince\ncounty\nhigherGeographychecar se posso compeltar um a partir do outro'

# %%
dados_sem_nan_e_fixos['higherGeography'].isna().sum()
# Out:
# 1

# %%
dados_sem_nan_e_fixos['stateProvince'].isna().sum()
# Out:
# 1

# %%
dados_sem_nan_e_fixos['county'].isna().sum()
# Out:
# 27

# %%
dados_sem_nan_e_fixos[dados_sem_nan_e_fixos['county'].isna()][['stateProvince', 'county', 'higherGeography']]
# Out:
#     stateProvince county higherGeography
# 10           Pará    NaN            Pará
# 33           Pará    NaN            Pará
# 69           Pará    NaN            Pará
# 128          Pará    NaN            Pará
# 145           NaN    NaN             NaN
# 173          Pará    NaN            Pará
# 301          Pará    NaN            Pará
# 311          Pará    NaN            Pará
# 375          Pará    NaN            Pará
# 533   Mato Grosso    NaN     Mato Grosso
# 538   Mato Grosso    NaN     Mato Grosso
# 542          Pará    NaN            Pará
# 543          Pará    NaN            Pará
# 544   Mato Grosso    NaN     Mato Grosso
# 545          Pará    NaN            Pará
# 549          Pará    NaN            Pará
# 551   Mato Grosso    NaN     Mato Grosso
# 555          Pará    NaN            Pará
# 556   Mato Grosso    NaN     Mato Grosso
# 557          Pará    NaN            Pará
# 560          Pará    NaN            Pará
# 561          Pará    NaN            Pará
# 562          Pará    NaN            Pará
# 570          Pará    NaN            Pará
# 579   Mato Grosso    NaN     Mato Grosso
# 665          Pará    NaN            Pará
# 697          Pará    NaN            Pará

# %% [markdown]
# Nao tem como definir os valores faltantes da coluna county a partir da coluna higherGeography. Quando a coluna county está faltante, a coluna higherGeography possui apenas o estado como valor

# %%
#tomar cuidado com os 'incertos' podem fuder o role

# %%
dados_sem_nan_e_fixos['acceptedScientificName'].unique()
# Out:
# array(['Pontoscolex', 'Liodrilus mendesi Righi, 1994',
#        'Heteromastus Eisig, 1887',
#        'Pontoscolex corethrurus (Muller, 1856)',
#        'Laeonereis culveri (Webster, 1879)', nan,
#        'Neanthes Kinberg, 1865',
#        'Rhinodrilus antonioi Hernández-García & Sousa, 2020',
#        'Hyperiodrilus africanus Beddard, 1891',
#        'Sigambra grubii Müller, 1858', 'Capitella Blainville, 1828',
#        'Laeonereis Hartman, 1945', 'Nephtys fluviatilis Monro, 1937',
#        'Righiodrilus tocantinensis (Righi, 1972)',
#        'Sigambra Müller, 1858', 'Notomastus M.Sars, 1851',
#        'Aphrodita Linnaeus, 1758', 'Urobenus petrerei Righi, 1985',
#        'Benhamia affinis Michaelsen, 1890',
#        'Dichogaster bolaui (Michaelsen, 1891)',
#        'Phragmatopoma caudata Krøyer, 1863', 'Namalycastis Hartman, 1959',
#        'Nereis Linnaeus, 1758', 'Clitellata',
#        'Rhinodrilus brasiliensis (Benham, 1886)',
#        'Aglaophamus Kinberg, 1866', 'Lumbriculidae', 'Terebellidae',
#        'Naididae', 'Haplotaxida', 'Dichogaster saliens (Beddard, 1893)',
#        'Urobenus Benham, 1886', 'Diachaeta Benham, 1886',
#        'Wegeneriella divergens itapecu Righi, Ayres & Bittencourt, 1978',
#        'Dichogaster bolaui bolaui',
#        'Dichogaster andina evae Righi, Ayres & Bittencourt, 1978',
#        'Rhinodrilus jucundus Righi, 1985',
#        'Centropygos joseensis Grube, 1859',
#        'Holoscolex Cognetti de Martiis, 1904', 'Turedrilus Righi, 1993',
#        'Dichogaster servi Righi & Ayres, 1975',
#        'Righiodrilus Zicsi, 1995', 'Rhinodrilus Perrier, 1872',
#        'Glossodrilus Cognetti de Martiis, 1905', 'Diaguita Cordero, 1942',
#        'Pontoscolex Schmarda, 1861', 'Andiorrhinus (Quibario) Quibario',
#        'Magelona F.Müller, 1858', 'Mediomastus Hartman, 1944',
#        'Capitella ovincola Hartman, 1947',
#        'Isolda pulchella Müller, 1858', 'Leodamas Kinberg, 1866',
#        'Boccardiella Blake & Kudenov, 1978', 'Loimia Malmgren, 1866',
#        'Phyllodoce Lamarck, 1818', 'Capitella capitata (Fabricius, 1780)',
#        'Alitta succinea (Leuckart, 1847)',
#        'Sabellaria wilsoni Lana & Gruet, 1989',
#        'Chaetacanthus Seidler, 1922', 'Hemipodia Kinberg, 1865',
#        'Syllis Lamarck, 1818', 'Bonuania Pillai, 1965',
#        'Marphysa Quatrefages, 1866', 'Eulalia Savigny, 1822',
#        'Ceratonereis Kinberg, 1865', 'Nereis oligohalina (Rioja, 1946)',
#        'Hydroides Gunnerus, 1768'], dtype=object)

# %%
campos_taxonomicos = ['typeStatus', 'phylum', 'class', 'order', 'family', 'genus', 'genericName', 'specificEpithet',
'infraspecificEpithet', 'taxonomicStatus', 'acceptedTaxonKey', 'phylumKey', 'classKey', 'orderKey', 'familyKey', 'genusKey',
'speciesKey', 'species', 'acceptedScientificName', 'verbatimScientificName']

# %%
dados_sem_nan_e_fixos[campos_taxonomicos].isna().sum().sum()
# Out:
# 6545

# %%
def preencher_campos_taxonomicos(row): #talvez de pra otimizar sem precisar do loop (sem precisar nomear cada coluna para testar individualmente!!)

  for campo_taxonomico in campos_taxonomicos:

    if pd.isna(row[campo_taxonomico]):

      # Filtra o DataFrame para registros correspondentes
            registro_correspondente = dados_sem_nan_e_fixos[
                (dados_sem_nan_e_fixos[campo_taxonomico].notna()) &
                (dados_sem_nan_e_fixos['acceptedScientificName'] == row['acceptedScientificName'])
            ]

            if not registro_correspondente.empty:

              # Preenche com o valor do registro correspondente
              valor_preenchimento = registro_correspondente.iloc[0][campo_taxonomico]
              row[campo_taxonomico] = valor_preenchimento


    return row

# %%
dados_sem_nan_e_fixos = dados_sem_nan_e_fixos.apply(preencher_campos_taxonomicos, axis = 1)

# %%
dados_sem_nan_e_fixos[campos_taxonomicos].isna().sum().sum()
# Out:
# 6384

# %% [markdown]
# Definir municipios nan de acordo com valores de latitude e longitude. Lembrar que esses valores decimais sao arredondados

# %%
api_key = 'AIzaSyA1i2SfD6tG3WaEQ2ap3caURfWSqdkMGVA'

# %%
geolocator = GoogleV3(api_key=api_key)

# %%
padrao = re.compile(r',\s*([^,-]*)(?:\s*-\s*|$)')

# %%
dados_sem_nan_e_fixos['county'].isna().sum()
# Out:
# 27

# %%
dados_sem_nan_e_fixos['locality'].isna().sum()
# Out:
# 1

# %%
def definir_campos_localizacao(row):

  latitude = row['decimalLatitude']

  longitude = row['decimalLongitude']

  if (pd.isna(longitude) or pd.isna(latitude)) or not pd.isna(row['county']):

    return row

  location = geolocator.reverse((latitude, longitude), exactly_one=True)

  cidade =  padrao.search(location[0])

  if cidade:

    row['county'] = cidade.group(1).strip()

    print(row['county'])

  return row

# %%
dados_sem_nan_e_fixos = dados_sem_nan_e_fixos.apply(definir_campos_localizacao, axis = 1)
# Out:
# Conceição do Araguaia

# %%
dados_sem_nan_e_fixos['county'].isna().sum()
# Out:
# 26

# %% [markdown]
# A maioria dos registros que não possuem localização de municipio, foram registrados em mar aberto

# %% [markdown]
# # ***Utilizar os dados abaixo:***

# %% [markdown]
# 145 das colunas não possuem nenhuma informação- em nenhum dos registros. Coloquei em uma lista pois vão ter que estar presentes no banco de dados por causa da exigencia da estrutura do gbif. Nesse caso, criar uma table separada para colocar um registro, tendo label de cada umas colunas como valor de um campo dessa table. Utilizar uma view (com transpose) para facilitar a concatenação dessas colunas sem informação junto com as demais para garantir a estrutura exigida pelo gbif.

# %% [markdown]
# 12 das colunas possuem valores fixos próprios para todos os registros. Coloquei em um dicionário para associar label de cada uma dessas colunas com o valor fixo delas para os registros. Além do valor fixo, o valor associado a cada chave possui também um elemento a mais: o indice do registro que possui qualquer variação em relação ao valor fixo. Ou seja, cada chave está associada a uma lista de 2 elementos [indice da excecao, valor fixo para a coluna]. O valor exceção é sempre um NaN (sem informacao nenhuma). Nesse caso, criar uma table separa para colocar associacao entre registros, excecao e valor fixo. Utilizar uma view (com transpose) para facilitar a concatenação dessas colunas fixas junto com as demais para garantir a estrutura exigida pelo gbif.

# %% [markdown]
# Em relação a normalização, atenção pois as colunas referentes a localização do registro possuem redundancia. Decidir quais utilizar no power bi.

# %%
dicionario_colunas_valores_fixo
# Out:
# {'accessRights': [<NA>,
#   'Creative Commons Attribution Non Commercial (CC-BY-NC) 4.0 License.'],
#  'license': [<NA>, 'CC_BY_NC_4_0'],
#  'rightsHolder': [<NA>, 'Museu Paraense Emílio Goeldi (MPEG)'],
#  'institutionCode': [<NA>, 'MPEG'],
#  'collectionCode': [<NA>, 'ANL'],
#  'basisOfRecord': [<NA>, 'PRESERVED_SPECIMEN'],
#  'occurrenceStatus': [<NA>, 'PRESENT'],
#  'datasetKey': [<NA>, '9c48ee0b-404a-4c84-9af0-946eef39ddca'],
#  'publishingCountry': [<NA>, 'BR'],
#  'protocol': [<NA>, 'EML'],
#  'lastCrawled': [<NA>, '2023-01-07T11:25:05.817Z'],
#  'continent': [145, 'SOUTH_AMERICA']}

# %%
lista_label_colunas_totalmente_nan
# Out:
# ['bibliographicCitation',
#  'language',
#  'modified',
#  'publisher',
#  'references',
#  'type',
#  'institutionID',
#  'collectionID',
#  'datasetID',
#  'datasetName',
#  'ownerInstitutionCode',
#  'informationWithheld',
#  'dataGeneralizations',
#  'dynamicProperties',
#  'recordNumber',
#  'recordedByID',
#  'individualCount',
#  'organismQuantity',
#  'organismQuantityType',
#  'sex',
#  'lifeStage',
#  'reproductiveCondition',
#  'behavior',
#  'establishmentMeans',
#  'degreeOfEstablishment',
#  'pathway',
#  'georeferenceVerificationStatus',
#  'disposition',
#  'associatedOccurrences',
#  'associatedReferences',
#  'associatedSequences',
#  'associatedTaxa',
#  'otherCatalogNumbers',
#  'occurrenceRemarks',
#  'organismID',
#  'organismName',
#  'organismScope',
#  'associatedOrganisms',
#  'previousIdentifications',
#  'organismRemarks',
#  'materialSampleID',
#  'eventID',
#  'parentEventID',
#  'fieldNumber',
#  'eventTime',
#  'startDayOfYear',
#  'endDayOfYear',
#  'verbatimEventDate',
#  'habitat',
#  'samplingProtocol',
#  'sampleSizeValue',
#  'sampleSizeUnit',
#  'samplingEffort',
#  'fieldNotes',
#  'locationID',
#  'higherGeographyID',
#  'waterBody',
#  'islandGroup',
#  'island',
#  'municipality',
#  'verbatimLocality',
#  'verbatimElevation',
#  'verticalDatum',
#  'verbatimDepth',
#  'minimumDistanceAboveSurfaceInMeters',
#  'maximumDistanceAboveSurfaceInMeters',
#  'locationAccordingTo',
#  'locationRemarks',
#  'coordinateUncertaintyInMeters',
#  'coordinatePrecision',
#  'pointRadiusSpatialFit',
#  'verbatimCoordinateSystem',
#  'verbatimSRS',
#  'footprintWKT',
#  'footprintSRS',
#  'footprintSpatialFit',
#  'georeferencedBy',
#  'georeferencedDate',
#  'georeferenceProtocol',
#  'georeferenceSources',
#  'georeferenceRemarks',
#  'geologicalContextID',
#  'earliestEonOrLowestEonothem',
#  'latestEonOrHighestEonothem',
#  'earliestEraOrLowestErathem',
#  'latestEraOrHighestErathem',
#  'earliestPeriodOrLowestSystem',
#  'latestPeriodOrHighestSystem',
#  'earliestEpochOrLowestSeries',
#  'latestEpochOrHighestSeries',
#  'earliestAgeOrLowestStage',
#  'latestAgeOrHighestStage',
#  'lowestBiostratigraphicZone',
#  'highestBiostratigraphicZone',
#  'lithostratigraphicTerms',
#  'group',
#  'formation',
#  'member',
#  'bed',
#  'identificationID',
#  'verbatimIdentification',
#  'identificationQualifier',
#  'identifiedBy',
#  'identifiedByID',
#  'dateIdentified',
#  'identificationReferences',
#  'identificationVerificationStatus',
#  'identificationRemarks',
#  'taxonID',
#  'scientificNameID',
#  'acceptedNameUsageID',
#  'parentNameUsageID',
#  'originalNameUsageID',
#  'nameAccordingToID',
#  'namePublishedInID',
#  'taxonConceptID',
#  'acceptedNameUsage',
#  'parentNameUsage',
#  'originalNameUsage',
#  'nameAccordingTo',
#  'namePublishedIn',
#  'namePublishedInYear',
#  'higherClassification',
#  'subfamily',
#  'subgenus',
#  'infragenericEpithet',
#  'cultivarEpithet',
#  'verbatimTaxonRank',
#  'vernacularName',
#  'nomenclaturalCode',
#  'nomenclaturalStatus',
#  'taxonRemarks',
#  'elevation',
#  'elevationAccuracy',
#  'depth',
#  'depthAccuracy',
#  'distanceFromCentroidInMeters',
#  'mediaType',
#  'subgenusKey',
#  'typifiedName',
#  'relativeOrganismQuantity',
#  'projectId',
#  'level3Gid',
#  'level3Name',
#  'eventType']

# %%
for column in dados_sem_nan_e_fixos.columns:

  if len(dados_sem_nan_e_fixos[column].unique()) < 30:

    print(column)
# Out:
# year
# month
# eventRemarks
# countryCode
# stateProvince
# typeStatus
# kingdom
# phylum
# class
# order
# family
# specificEpithet
# infraspecificEpithet
# taxonRank
# taxonomicStatus
# lastInterpreted
# issue
# hasCoordinate
# hasGeospatialIssues
# kingdomKey
# phylumKey
# classKey
# orderKey
# familyKey
# speciesKey
# species
# lastParsed
# repatriated
# level0Gid
# level0Name
# level1Gid
# level1Name
# iucnRedListCategory

# %%
dados_sem_nan_e_fixos.head()
# Out:
#        gbifID     occurrenceID    catalogNumber  \
# 0  2365686427  MPEG.ANL 001101  MPEG.ANL 001101
# 1  2365686418  MPEG.ANL 001596  MPEG.ANL 001596
# 2  2365686416  MPEG.ANL 001635  MPEG.ANL 001635
# 3  2365686414  MPEG.ANL 001031  MPEG.ANL 001031
# 4  2365686412  MPEG.ANL 001036  MPEG.ANL 001036
#
#                                           recordedBy preparations  \
# 0          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
# 1  Sousa, Sandriel; Hernández, Luis; Rousseau, Gu...   Etanol - 1
# 2      Sousa, Anny; Sousa, Sandriel; Hernández, Luis   Etanol - 1
# 3          Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 1
# 4          Beckman, Ruana; Pena, José; Souza, Raíssa  Etanol - 17
#
#              eventDate    year  month   day eventRemarks     higherGeography  \
# 0  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 1  2018-08-15T00:00:00  2018.0    8.0  15.0          NaN  Maranhão, São Luís
# 2  2019-02-12T00:00:00  2019.0    2.0  12.0          NaN    Maranhão, Caxias
# 3  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
# 4  2017-08-30T00:00:00  2017.0    8.0  30.0          NaN         Pará, Belém
#
#   countryCode stateProvince    county              locality  decimalLatitude  \
# 0          BR          Pará     Belém               Mocambo         1.440694
# 1          BR      Maranhão  São Luís        Fazenda Escola        -4.587222
# 2          BR      Maranhão    Caxias  Santa Tereza Village        -4.899722
# 3          BR          Pará     Belém               Mocambo         1.440694
# 4          BR          Pará     Belém               Mocambo         1.440694
#
#    decimalLongitude typeStatus                 scientificName   kingdom  \
# 0        -48.411250   PARATYPE                    Pontoscolex  Animalia
# 1        -44.208611        NaN  Liodrilus mendesi Righi, 1994  Animalia
# 2        -43.470833        NaN  Liodrilus mendesi Righi, 1994  Animalia
# 3        -48.411250   PARATYPE                    Pontoscolex  Animalia
# 4        -48.411250   PARATYPE                    Pontoscolex  Animalia
#
#      phylum       class        order            family        genus  \
# 0  Annelida  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex
# 1  Annelida  Clitellata          NaN               NaN    Liodrilus
# 2  Annelida  Clitellata          NaN               NaN    Liodrilus
# 3  Annelida  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex
# 4  Annelida  Clitellata  Haplotaxida  Glossoscolecidae  Pontoscolex
#
#    genericName specificEpithet infraspecificEpithet taxonRank taxonomicStatus  \
# 0  Pontoscolex             NaN                  NaN     GENUS        DOUBTFUL
# 1    Liodrilus         mendesi                  NaN   SPECIES        ACCEPTED
# 2    Liodrilus         mendesi                  NaN   SPECIES        ACCEPTED
# 3  Pontoscolex             NaN                  NaN     GENUS        DOUBTFUL
# 4  Pontoscolex             NaN                  NaN     GENUS        DOUBTFUL
#
#             lastInterpreted  \
# 0  2023-09-07T09:19:05.952Z
# 1  2023-09-07T09:19:05.949Z
# 2  2023-09-07T09:19:05.937Z
# 3  2023-09-07T09:19:05.946Z
# 4  2023-09-07T09:19:05.946Z
#
#                                                issue  hasCoordinate  \
# 0  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 1  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 2  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 3  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 4  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
#
#    hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                 True   2308740         2308740.0           1       42.0
# 1                False   9512479         9512479.0           1       42.0
# 2                False   9512479         9512479.0           1       42.0
# 3                 True   2308740         2308740.0           1       42.0
# 4                 True   2308740         2308740.0           1       42.0
#
#    classKey  orderKey  familyKey   genusKey  speciesKey            species  \
# 0     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 1     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 2     255.0       NaN        NaN  4813824.0   9512479.0  Liodrilus mendesi
# 3     255.0     472.0     3567.0  2308740.0         NaN                NaN
# 4     255.0     472.0     3567.0  2308740.0         NaN                NaN
#
#           acceptedScientificName   verbatimScientificName  \
# 0                    Pontoscolex  Pontoscolex Corethrurus
# 1  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 2  Liodrilus mendesi Righi, 1994        Liodrilus mendesi
# 3                    Pontoscolex  Pontoscolex Corethrurus
# 4                    Pontoscolex  Pontoscolex Corethrurus
#
#                  lastParsed repatriated level0Gid level0Name level1Gid  \
# 0  2023-09-07T09:19:05.952Z       false      None       None      None
# 1  2023-09-07T09:19:05.949Z       false       BRA     Brazil  BRA.10_1
# 2  2023-09-07T09:19:05.937Z       false       BRA     Brazil  BRA.10_1
# 3  2023-09-07T09:19:05.946Z       false      None       None      None
# 4  2023-09-07T09:19:05.946Z       false      None       None      None
#
#   level1Name    level2Gid level2Name iucnRedListCategory
# 0       None         None       None                None
# 1   Maranhão  BRA.10.59_2       Codó                  NE
# 2   Maranhão  BRA.10.52_2     Caxias                  NE
# 3       None         None       None                None
# 4       None         None       None                None

# %%
dicionario_colunas_interdepentens = {'eventDate' : ['year', 'month', 'day'],
                                     'higherGeography': ['stateProvince', 'county'],
                                     'scientificName': ['genus', 'genericName', 'specificEpithet', 'infraspecificEpithet', 'taxonKey', 'acceptedTaxonKey', 'speciesKey', 'species', 'acceptedScientificName', 'verbatimScientificName'],
                                     'kingdom': 'kingdomKey',
                                     'phylum': 'phylumKey',
                                     'class': 'classKey',
                                     'order': 'orderKey',
                                     'family': 'familyKey',
                                     'genus': 'genusKey',
                                     'lastInterpreted': 'lastParsed',
                                     'countryCode': ['level0Gid', 'level0Name', 'level1Gid', 'level2Gid	'],
                                     'stateProvince': 'level1Name',
                                     }

# %%
lista_colunas_menos_30_valores_unicos = []

for column in dados_sem_nan_e_fixos.columns:

  if len(dados_sem_nan_e_fixos[column].unique()) < 30:

    lista_colunas_menos_30_valores_unicos.append(column)

# %%
lista_colunas_menos_30_valores_unicos
# Out:
# ['year',
#  'month',
#  'eventRemarks',
#  'countryCode',
#  'stateProvince',
#  'typeStatus',
#  'kingdom',
#  'phylum',
#  'class',
#  'order',
#  'family',
#  'specificEpithet',
#  'infraspecificEpithet',
#  'taxonRank',
#  'taxonomicStatus',
#  'lastInterpreted',
#  'issue',
#  'hasCoordinate',
#  'hasGeospatialIssues',
#  'kingdomKey',
#  'phylumKey',
#  'classKey',
#  'orderKey',
#  'familyKey',
#  'speciesKey',
#  'species',
#  'lastParsed',
#  'repatriated',
#  'level0Gid',
#  'level0Name',
#  'level1Gid',
#  'level1Name',
#  'iucnRedListCategory']

# %%
for column1 in dados_sem_nan_e_fixos.columns:

  print(column1)

  for column2 in dados_sem_nan_e_fixos.columns:
      if column1 == column2:
          continue

      filtro = dados_sem_nan_e_fixos[[column1, column2]].notnull().all(axis=1)

      valores_unicos = dados_sem_nan_e_fixos.loc[filtro, [column1, column2]].drop_duplicates()

      for index, row in valores_unicos.iterrows():

          filtro_combinacao = (dados_sem_nan_e_fixos[column1].isnull()) & (dados_sem_nan_e_fixos[column2] == row[column2])

          dados_sem_nan_e_fixos.loc[filtro_combinacao, column1] = row[column1]
# Out:
# gbifID
# occurrenceID
# catalogNumber
# recordedBy
# preparations
# eventDate
# year
# month
# day
# eventRemarks
# higherGeography
# countryCode
# stateProvince
# county
# locality
# decimalLatitude
# decimalLongitude
# typeStatus
# scientificName
# kingdom
# phylum
# class
# order
# family
# genus
# genericName
# specificEpithet
# infraspecificEpithet
# taxonRank
# taxonomicStatus
# lastInterpreted
# issue
# hasCoordinate
# hasGeospatialIssues
# taxonKey
# acceptedTaxonKey
# kingdomKey
# phylumKey
# classKey
# orderKey
# familyKey
# genusKey
# speciesKey
# species
# acceptedScientificName
# verbatimScientificName
# lastParsed
# repatriated
# level0Gid
# level0Name
# level1Gid
# level1Name
# level2Gid
# level2Name
# iucnRedListCategory

# %%
dados_sem_nan_e_fixos
# Out:
#          gbifID     occurrenceID    catalogNumber  \
# 0    2365686427  MPEG.ANL 001101  MPEG.ANL 001101
# 1    2365686418  MPEG.ANL 001596  MPEG.ANL 001596
# 2    2365686416  MPEG.ANL 001635  MPEG.ANL 001635
# 3    2365686414  MPEG.ANL 001031  MPEG.ANL 001031
# 4    2365686412  MPEG.ANL 001036  MPEG.ANL 001036
# ..          ...              ...              ...
# 887  1438492475  MPEG.ANL 000009  MPEG.ANL 000009
# 888  1438492474  MPEG.ANL 000023  MPEG.ANL 000023
# 889  1438492473  MPEG.ANL 000019  MPEG.ANL 000019
# 890  1438492472  MPEG.ANL 000024  MPEG.ANL 000024
# 891  1438492471  MPEG.ANL 000010  MPEG.ANL 000010
#
#                                             recordedBy preparations  \
# 0            Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 3
# 1    Sousa, Sandriel; Hernández, Luis; Rousseau, Gu...   Etanol - 1
# 2        Sousa, Anny; Sousa, Sandriel; Hernández, Luis   Etanol - 1
# 3            Beckman, Ruana; Pena, José; Souza, Raíssa   Etanol - 1
# 4            Beckman, Ruana; Pena, José; Souza, Raíssa  Etanol - 17
# ..                                                 ...          ...
# 887                            Lavelle, P. ; ,  Equipe   Etanol - 7
# 888                            Lavelle, P. ; ,  Equipe   Etanol - 2
# 889                            Lavelle, P. ; ,  Equipe   Etanol - 2
# 890                            Lavelle, P. ; ,  Equipe   Etanol - 1
# 891                            Lavelle, P. ; ,  Equipe   Etanol - 4
#
#                eventDate    year  month   day      eventRemarks  \
# 0    2017-08-30T00:00:00  2017.0    8.0  30.0  Recifes Arenosos
# 1    2018-08-15T00:00:00  2018.0    8.0  15.0  Recifes Arenosos
# 2    2019-02-12T00:00:00  2019.0    2.0  12.0  Recifes Arenosos
# 3    2017-08-30T00:00:00  2017.0    8.0  30.0  Recifes Arenosos
# 4    2017-08-30T00:00:00  2017.0    8.0  30.0  Recifes Arenosos
# ..                   ...     ...    ...   ...               ...
# 887  2008-06-04T00:00:00  2008.0    6.0   4.0  Recifes Arenosos
# 888  2008-06-04T00:00:00  2008.0    6.0   4.0  Recifes Arenosos
# 889  2008-06-04T00:00:00  2008.0    6.0   4.0  Recifes Arenosos
# 890  2008-06-04T00:00:00  2008.0    6.0   4.0  Recifes Arenosos
# 891  2008-06-04T00:00:00  2008.0    6.0   4.0  Recifes Arenosos
#
#         higherGeography countryCode stateProvince        county  \
# 0           Pará, Belém          BR          Pará         Belém
# 1    Maranhão, São Luís          BR      Maranhão      São Luís
# 2      Maranhão, Caxias          BR      Maranhão        Caxias
# 3           Pará, Belém          BR          Pará         Belém
# 4           Pará, Belém          BR          Pará         Belém
# ..                  ...         ...           ...           ...
# 887  Pará, Nova Ipixuna          BR          Pará  Nova Ipixuna
# 888  Pará, Nova Ipixuna          BR          Pará  Nova Ipixuna
# 889  Pará, Nova Ipixuna          BR          Pará  Nova Ipixuna
# 890  Pará, Nova Ipixuna          BR          Pará  Nova Ipixuna
# 891  Pará, Nova Ipixuna          BR          Pará  Nova Ipixuna
#
#                        locality  decimalLatitude  decimalLongitude typeStatus  \
# 0                       Mocambo         1.440694        -48.411250   PARATYPE
# 1                Fazenda Escola        -4.587222        -44.208611   PARATYPE
# 2          Santa Tereza Village        -4.899722        -43.470833   PARATYPE
# 3                       Mocambo         1.440694        -48.411250   PARATYPE
# 4                       Mocambo         1.440694        -48.411250   PARATYPE
# ..                          ...              ...               ...        ...
# 887     Maçaranduba-Lote Galbão        -4.806111        -49.317778   PARATYPE
# 888  Maçaranduba-Lote Zé Rondon        -4.806111        -49.317778   PARATYPE
# 889   Maçaranduba-Lote Jurandir        -4.806111        -49.317778   PARATYPE
# 890   Maçaranduba-Lote Jurandir        -4.806111        -49.317778   PARATYPE
# 891       Maçaranduba-Lote Geni        -4.806111        -49.317778   PARATYPE
#
#                              scientificName   kingdom    phylum       class  \
# 0                               Pontoscolex  Animalia  Annelida  Clitellata
# 1             Liodrilus mendesi Righi, 1994  Animalia  Annelida  Clitellata
# 2             Liodrilus mendesi Righi, 1994  Animalia  Annelida  Clitellata
# 3                               Pontoscolex  Animalia  Annelida  Clitellata
# 4                               Pontoscolex  Animalia  Annelida  Clitellata
# ..                                      ...       ...       ...         ...
# 887  Pontoscolex corethrurus (Muller, 1856)  Animalia  Annelida  Clitellata
# 888  Pontoscolex corethrurus (Muller, 1856)  Animalia  Annelida  Clitellata
# 889  Pontoscolex corethrurus (Muller, 1856)  Animalia  Annelida  Clitellata
# 890  Pontoscolex corethrurus (Muller, 1856)  Animalia  Annelida  Clitellata
# 891  Pontoscolex corethrurus (Muller, 1856)  Animalia  Annelida  Clitellata
#
#                 order            family        genus  genericName  \
# 0         Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex
# 1    Crassiclitellata        Eudrilidae    Liodrilus    Liodrilus
# 2    Crassiclitellata     Rhinodrilidae    Liodrilus    Liodrilus
# 3         Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex
# 4         Haplotaxida  Glossoscolecidae  Pontoscolex  Pontoscolex
# ..                ...               ...          ...          ...
# 887  Crassiclitellata     Rhinodrilidae  Pontoscolex  Pontoscolex
# 888  Crassiclitellata     Rhinodrilidae  Pontoscolex  Pontoscolex
# 889  Crassiclitellata     Rhinodrilidae  Pontoscolex  Pontoscolex
# 890  Crassiclitellata     Rhinodrilidae  Pontoscolex  Pontoscolex
# 891  Crassiclitellata     Rhinodrilidae  Pontoscolex  Pontoscolex
#
#     specificEpithet infraspecificEpithet taxonRank taxonomicStatus  \
# 0            bolaui              itapecu     GENUS        DOUBTFUL
# 1           mendesi              itapecu   SPECIES        ACCEPTED
# 2           mendesi              itapecu   SPECIES        ACCEPTED
# 3           mendesi              itapecu     GENUS        DOUBTFUL
# 4            bolaui              itapecu     GENUS        DOUBTFUL
# ..              ...                  ...       ...             ...
# 887     corethrurus                 evae   SPECIES        ACCEPTED
# 888     corethrurus                 evae   SPECIES        ACCEPTED
# 889     corethrurus                 evae   SPECIES        ACCEPTED
# 890     corethrurus              itapecu   SPECIES        ACCEPTED
# 891     corethrurus              itapecu   SPECIES        ACCEPTED
#
#               lastInterpreted  \
# 0    2023-09-07T09:19:05.952Z
# 1    2023-09-07T09:19:05.949Z
# 2    2023-09-07T09:19:05.937Z
# 3    2023-09-07T09:19:05.946Z
# 4    2023-09-07T09:19:05.946Z
# ..                        ...
# 887  2023-09-07T09:19:05.950Z
# 888  2023-09-07T09:19:05.952Z
# 889  2023-09-07T09:19:05.949Z
# 890  2023-09-07T09:19:05.952Z
# 891  2023-09-07T09:19:05.950Z
#
#                                                  issue  hasCoordinate  \
# 0    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 1    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 2    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 3    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 4    COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# ..                                                 ...            ...
# 887  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 888  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 889  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 890  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
# 891  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS8...           True
#
#      hasGeospatialIssues  taxonKey  acceptedTaxonKey  kingdomKey  phylumKey  \
# 0                   True   2308740         2308740.0           1       42.0
# 1                  False   9512479         9512479.0           1       42.0
# 2                  False   9512479         9512479.0           1       42.0
# 3                   True   2308740         2308740.0           1       42.0
# 4                   True   2308740         2308740.0           1       42.0
# ..                   ...       ...               ...         ...        ...
# 887                False   2308741         2308741.0           1       42.0
# 888                False   2308741         2308741.0           1       42.0
# 889                False   2308741         2308741.0           1       42.0
# 890                False   2308741         2308741.0           1       42.0
# 891                False   2308741         2308741.0           1       42.0
#
#      classKey   orderKey  familyKey    genusKey  speciesKey  \
# 0       255.0      472.0     3567.0   2308740.0   4410238.0
# 1       255.0  5958860.0  4288888.0   4813824.0   9512479.0
# 2       255.0  5958860.0  9272891.0   4813824.0   9512479.0
# 3       255.0      472.0     3567.0   2308740.0   9512479.0
# 4       255.0      472.0     3567.0   2308740.0   4410238.0
# ..        ...        ...        ...         ...         ...
# 887     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 888     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 889     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 890     255.0  5958860.0  9272891.0  10943108.0   2308741.0
# 891     255.0  5958860.0  9272891.0  10943108.0   2308741.0
#
#                      species                  acceptedScientificName  \
# 0         Dichogaster bolaui                             Pontoscolex
# 1          Liodrilus mendesi           Liodrilus mendesi Righi, 1994
# 2          Liodrilus mendesi           Liodrilus mendesi Righi, 1994
# 3          Liodrilus mendesi                             Pontoscolex
# 4         Dichogaster bolaui                             Pontoscolex
# ..                       ...                                     ...
# 887  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 888  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 889  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 890  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
# 891  Pontoscolex corethrurus  Pontoscolex corethrurus (Muller, 1856)
#
#       verbatimScientificName                lastParsed repatriated level0Gid  \
# 0    Pontoscolex Corethrurus  2023-09-07T09:19:05.952Z       false       BRA
# 1          Liodrilus mendesi  2023-09-07T09:19:05.949Z       false       BRA
# 2          Liodrilus mendesi  2023-09-07T09:19:05.937Z       false       BRA
# 3    Pontoscolex Corethrurus  2023-09-07T09:19:05.946Z       false       BRA
# 4    Pontoscolex Corethrurus  2023-09-07T09:19:05.946Z       false       BRA
# ..                       ...                       ...         ...       ...
# 887  Pontoscolex corethrurus  2023-09-07T09:19:05.950Z       false       BRA
# 888  Pontoscolex corethrurus  2023-09-07T09:19:05.952Z       false       BRA
# 889  Pontoscolex corethrurus  2023-09-07T09:19:05.949Z       false       BRA
# 890  Pontoscolex corethrurus  2023-09-07T09:19:05.952Z       false       BRA
# 891  Pontoscolex corethrurus  2023-09-07T09:19:05.950Z       false       BRA
#
#     level0Name level1Gid level1Name    level2Gid    level2Name  \
# 0       Brazil  BRA.14_1       Pará  BRA.14.19_2         Belém
# 1       Brazil  BRA.10_1   Maranhão  BRA.10.59_2          Codó
# 2       Brazil  BRA.10_1   Maranhão  BRA.10.52_2        Caxias
# 3       Brazil  BRA.14_1       Pará  BRA.14.19_2         Belém
# 4       Brazil  BRA.14_1       Pará  BRA.14.19_2         Belém
# ..         ...       ...        ...          ...           ...
# 887     Brazil  BRA.14_1       Pará  BRA.14.78_2  Nova Ipixuna
# 888     Brazil  BRA.14_1       Pará  BRA.14.78_2  Nova Ipixuna
# 889     Brazil  BRA.14_1       Pará  BRA.14.78_2  Nova Ipixuna
# 890     Brazil  BRA.14_1       Pará  BRA.14.78_2  Nova Ipixuna
# 891     Brazil  BRA.14_1       Pará  BRA.14.78_2  Nova Ipixuna
#
#     iucnRedListCategory
# 0                    NE
# 1                    NE
# 2                    NE
# 3                    NE
# 4                    NE
# ..                  ...
# 887                  NE
# 888                  NE
# 889                  NE
# 890                  NE
# 891                  NE
#
# [892 rows x 55 columns]
